# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
#from config import weather_api_key
weather_api_key = "c334a28706460f469f090fde04b34da0"
# Import the datetime module from the datetime library.
from datetime import datetime
import json
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather
print(city_weather["weather"][0]["description"])
# Out:
# overcast clouds

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 1 | nizhniy odes
# Processing Record 4 of Set 1 | mitsamiouli
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | cockburn town
# Processing Record 8 of Set 1 | kilindoni
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | san jose
# Processing Record 15 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | devils lake
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | bonavista
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | isangel
# Processing Record 28 of Set 1 | kalmar
# Processing Record 29 of Set 1 | choma
# Processing Record 30 of Set 1 | vanavara
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | berlevag
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | two rivers
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | belmonte
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | virginia beach
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | salalah
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | nanortalik
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | sinnamary
# Processing Record 2 of Set 2 | sur
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | loei
# Processing Record 5 of Set 2 | oxbow
# Processing Record 6 of Set 2 | torres
# Processing Record 7 of Set 2 | lata
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | umm ruwabah
# City not found. Skipping...
# Processing Record 10 of Set 2 | peniche
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | tigil
# Processing Record 15 of Set 2 | chauk
# Processing Record 16 of Set 2 | ca mau
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | los llanos de aridane
# Processing Record 21 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | anloga
# Processing Record 24 of Set 2 | bambanglipuro
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | monteria
# Processing Record 28 of Set 2 | wattegama
# Processing Record 29 of Set 2 | santa vitoria do palmar
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | san andres
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | boende
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | atlantic city
# Processing Record 38 of Set 2 | qarqin
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | tevaitoa
# Processing Record 44 of Set 2 | libreville
# Processing Record 45 of Set 2 | tiarei
# Processing Record 46 of Set 2 | tabira
# Processing Record 47 of Set 2 | port-gentil
# Processing Record 48 of Set 2 | hopfgarten
# Processing Record 49 of Set 2 | floresta
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 3 | vredendal
# Processing Record 5 of Set 3 | black river
# Processing Record 6 of Set 3 | xai-xai
# Processing Record 7 of Set 3 | khorinsk
# Processing Record 8 of Set 3 | raymondville
# Processing Record 9 of Set 3 | mahebourg
# Processing Record 10 of Set 3 | la ronge
# Processing Record 11 of Set 3 | severo-yeniseyskiy
# Processing Record 12 of Set 3 | yumen
# Processing Record 13 of Set 3 | nemuro
# Processing Record 14 of Set 3 | baherden
# Processing Record 15 of Set 3 | mana
# Processing Record 16 of Set 3 | college
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | hirara
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | paucartambo
# City not found. Skipping...
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | port blair
# Processing Record 26 of Set 3 | saint-joseph
# Processing Record 27 of Set 3 | cleethorpes
# Processing Record 28 of Set 3 | asilah
# Processing Record 29 of Set 3 | suntar
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | palu
# Processing Record 32 of Set 3 | sitka
# Processing Record 33 of Set 3 | kalmunai
# Processing Record 34 of Set 3 | verkhoyansk
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | lavrentiya
# Processing Record 37 of Set 3 | west bay
# Processing Record 38 of Set 3 | leningradskiy
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | neuruppin
# Processing Record 41 of Set 3 | karratha
# Processing Record 42 of Set 3 | oranjemund
# Processing Record 43 of Set 3 | poum
# Processing Record 44 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 3 | manali
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | rawson
# Processing Record 48 of Set 3 | mersing
# Processing Record 49 of Set 3 | havoysund
# Processing Record 50 of Set 3 | opuwo
# Processing Record 1 of Set 4 | ndola
# Processing Record 2 of Set 4 | altay
# Processing Record 3 of Set 4 | qinzhou
# Processing Record 4 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 4 | shimoda
# Processing Record 6 of Set 4 | hay river
# Processing Record 7 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 4 | huaicheng
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | ulaanbaatar
# Processing Record 11 of Set 4 | meadow lake
# Processing Record 12 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 4 | beibei
# Processing Record 14 of Set 4 | huicungo
# Processing Record 15 of Set 4 | parnarama
# Processing Record 16 of Set 4 | pacific grove
# Processing Record 17 of Set 4 | quatre cocos
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | bluff
# Processing Record 20 of Set 4 | lucknow
# Processing Record 21 of Set 4 | puerto escondido
# Processing Record 22 of Set 4 | ilulissat
# Processing Record 23 of Set 4 | lyuban
# Processing Record 24 of Set 4 | kutum
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | zuenoula
# Processing Record 27 of Set 4 | bredasdorp
# Processing Record 28 of Set 4 | la rioja
# Processing Record 29 of Set 4 | lubbock
# Processing Record 30 of Set 4 | pokhara
# Processing Record 31 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | guarapari
# Processing Record 33 of Set 4 | clyde river
# Processing Record 34 of Set 4 | hithadhoo
# Processing Record 35 of Set 4 | pingliang
# Processing Record 36 of Set 4 | wangqing
# Processing Record 37 of Set 4 | pitsunda
# Processing Record 38 of Set 4 | fort nelson
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | harnai
# Processing Record 41 of Set 4 | svetlogorsk
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | tammisaari
# Processing Record 44 of Set 4 | srednekolymsk
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | yulara
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | aykhal
# Processing Record 1 of Set 5 | serebryansk
# Processing Record 2 of Set 5 | flinders
# Processing Record 3 of Set 5 | scalea
# Processing Record 4 of Set 5 | corn island
# Processing Record 5 of Set 5 | butaritari
# Processing Record 6 of Set 5 | coffs harbour
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | caravelas
# Processing Record 10 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | nishihara
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | namie
# Processing Record 15 of Set 5 | nhulunbuy
# Processing Record 16 of Set 5 | vogosca
# Processing Record 17 of Set 5 | lorengau
# Processing Record 18 of Set 5 | cedar city
# Processing Record 19 of Set 5 | leh
# Processing Record 20 of Set 5 | ahipara
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | abu dhabi
# Processing Record 23 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 5 | spruce grove
# Processing Record 25 of Set 5 | alta floresta
# Processing Record 26 of Set 5 | taoudenni
# Processing Record 27 of Set 5 | port keats
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | grindavik
# Processing Record 32 of Set 5 | san patricio
# Processing Record 33 of Set 5 | tiksi
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | itaituba
# Processing Record 37 of Set 5 | san juan bautista
# Processing Record 38 of Set 5 | chokurdakh
# Processing Record 39 of Set 5 | zwedru
# Processing Record 40 of Set 5 | sisimiut
# Processing Record 41 of Set 5 | contamana
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | jaena
# Processing Record 44 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 5 | eureka
# Processing Record 46 of Set 5 | pyinmana
# Processing Record 47 of Set 5 | rockhampton
# Processing Record 48 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | venado tuerto
# Processing Record 50 of Set 5 | mangan
# Processing Record 1 of Set 6 | gat
# Processing Record 2 of Set 6 | banda aceh
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | egvekinot
# Processing Record 5 of Set 6 | yellowknife
# Processing Record 6 of Set 6 | stornoway
# Processing Record 7 of Set 6 | the valley
# Processing Record 8 of Set 6 | boone
# Processing Record 9 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 6 | nome
# Processing Record 11 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 6 | ozernovskiy
# Processing Record 14 of Set 6 | byron bay
# Processing Record 15 of Set 6 | half moon bay
# Processing Record 16 of Set 6 | senekal
# Processing Record 17 of Set 6 | maldonado
# Processing Record 18 of Set 6 | tagbina
# Processing Record 19 of Set 6 | provideniya
# Processing Record 20 of Set 6 | kavaratti
# Processing Record 21 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 6 | saint-augustin
# Processing Record 23 of Set 6 | arkhangelos
# City not found. Skipping...
# Processing Record 24 of Set 6 | shubarshi
# Processing Record 25 of Set 6 | tabuk
# Processing Record 26 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 6 | adamas
# Processing Record 28 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 29 of Set 6 | westport
# Processing Record 30 of Set 6 | sydney
# Processing Record 31 of Set 6 | ginda
# Processing Record 32 of Set 6 | mandalgovi
# Processing Record 33 of Set 6 | camacha
# Processing Record 34 of Set 6 | tynset
# Processing Record 35 of Set 6 | mehamn
# Processing Record 36 of Set 6 | bridlington
# Processing Record 37 of Set 6 | longyearbyen
# Processing Record 38 of Set 6 | nakamura
# Processing Record 39 of Set 6 | kropotkin
# Processing Record 40 of Set 6 | san francisco del mar
# Processing Record 41 of Set 6 | tambacounda
# Processing Record 42 of Set 6 | chimichagua
# Processing Record 43 of Set 6 | kayerkan
# Processing Record 44 of Set 6 | chor
# Processing Record 45 of Set 6 | pevek
# Processing Record 46 of Set 6 | adrar
# Processing Record 47 of Set 6 | marshall
# Processing Record 48 of Set 6 | gemena
# Processing Record 49 of Set 6 | naifaru
# Processing Record 50 of Set 6 | chimoio
# Processing Record 1 of Set 7 | dabat
# Processing Record 2 of Set 7 | vila franca do campo
# Processing Record 3 of Set 7 | namibe
# Processing Record 4 of Set 7 | havre-saint-pierre
# Processing Record 5 of Set 7 | novyy urengoy
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | kysyl-syr
# Processing Record 8 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 7 | sorland
# Processing Record 10 of Set 7 | la orilla
# Processing Record 11 of Set 7 | chicama
# Processing Record 12 of Set 7 | viedma
# Processing Record 13 of Set 7 | sao filipe
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | solnechnyy
# Processing Record 16 of Set 7 | boyuibe
# Processing Record 17 of Set 7 | hellvik
# Processing Record 18 of Set 7 | hit
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 7 | verkhnevilyuysk
# Processing Record 22 of Set 7 | araouane
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | barrow
# Processing Record 25 of Set 7 | madras
# Processing Record 26 of Set 7 | mareeba
# Processing Record 27 of Set 7 | humboldt
# Processing Record 28 of Set 7 | nchelenge
# Processing Record 29 of Set 7 | aksarka
# Processing Record 30 of Set 7 | sanduleni
# Processing Record 31 of Set 7 | amapa
# Processing Record 32 of Set 7 | margate
# Processing Record 33 of Set 7 | suzdal
# Processing Record 34 of Set 7 | manavalakurichi
# Processing Record 35 of Set 7 | santa fe
# Processing Record 36 of Set 7 | cabinda
# Processing Record 37 of Set 7 | sajanan
# Processing Record 38 of Set 7 | guerrero negro
# Processing Record 39 of Set 7 | nuuk
# Processing Record 40 of Set 7 | azanka
# Processing Record 41 of Set 7 | kavieng
# Processing Record 42 of Set 7 | kiama
# Processing Record 43 of Set 7 | gorele
# Processing Record 44 of Set 7 | fuerte olimpo
# Processing Record 45 of Set 7 | do gonbadan
# Processing Record 46 of Set 7 | coahuayana
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | lagoa
# Processing Record 49 of Set 7 | vostok
# Processing Record 50 of Set 7 | mandali
# Processing Record 1 of Set 8 | cherlak
# Processing Record 2 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 3 of Set 8 | bengkulu
# Processing Record 4 of Set 8 | furano
# Processing Record 5 of Set 8 | gerash
# Processing Record 6 of Set 8 | saint anthony
# Processing Record 7 of Set 8 | gaffney
# Processing Record 8 of Set 8 | lodwar
# Processing Record 9 of Set 8 | muyezerskiy
# Processing Record 10 of Set 8 | noumea
# Processing Record 11 of Set 8 | ginir
# Processing Record 12 of Set 8 | ornskoldsvik
# Processing Record 13 of Set 8 | bud
# Processing Record 14 of Set 8 | khani
# Processing Record 15 of Set 8 | kijang
# Processing Record 16 of Set 8 | bahia de caraquez
# Processing Record 17 of Set 8 | riberalta
# Processing Record 18 of Set 8 | sambava
# Processing Record 19 of Set 8 | plettenberg bay
# Processing Record 20 of Set 8 | road town
# Processing Record 21 of Set 8 | san pedro
# Processing Record 22 of Set 8 | kenai
# Processing Record 23 of Set 8 | dharchula
# Processing Record 24 of Set 8 | ketchikan
# Processing Record 25 of Set 8 | baruun-urt
# Processing Record 26 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 8 | impfondo
# Processing Record 28 of Set 8 | husavik
# Processing Record 29 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 8 | veraval
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | jinchang
# Processing Record 33 of Set 8 | kirakira
# Processing Record 34 of Set 8 | belyy yar
# Processing Record 35 of Set 8 | tutoia
# Processing Record 36 of Set 8 | aleksandrov
# Processing Record 37 of Set 8 | san ramon
# Processing Record 38 of Set 8 | lincoln
# Processing Record 39 of Set 8 | nova vicosa
# Processing Record 40 of Set 8 | sept-iles
# Processing Record 41 of Set 8 | amga
# Processing Record 42 of Set 8 | nova olinda do norte
# Processing Record 43 of Set 8 | kaeo
# Processing Record 44 of Set 8 | tamandare
# Processing Record 45 of Set 8 | houma
# Processing Record 46 of Set 8 | amarillo
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | aconibe
# Processing Record 49 of Set 8 | ormara
# Processing Record 50 of Set 8 | raudeberg
# Processing Record 1 of Set 9 | aklavik
# Processing Record 2 of Set 9 | coos bay
# Processing Record 3 of Set 9 | labrea
# Processing Record 4 of Set 9 | tres arroyos
# Processing Record 5 of Set 9 | kitob
# Processing Record 6 of Set 9 | rio grande
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | saint-pierre
# Processing Record 9 of Set 9 | yusva
# City not found. Skipping...
# Processing Record 10 of Set 9 | launceston
# Processing Record 11 of Set 9 | aksay
# Processing Record 12 of Set 9 | vicam
# Processing Record 13 of Set 9 | aquiraz
# Processing Record 14 of Set 9 | mweka
# Processing Record 15 of Set 9 | vallenar
# Processing Record 16 of Set 9 | labuhan
# Processing Record 17 of Set 9 | rocha
# Processing Record 18 of Set 9 | valparaiso
# Processing Record 19 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 20 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 9 | thongwa
# Processing Record 22 of Set 9 | innisfail
# Processing Record 23 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 9 | ambad
# Processing Record 25 of Set 9 | bilibino
# Processing Record 26 of Set 9 | ryotsu
# Processing Record 27 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 28 of Set 9 | abnub
# Processing Record 29 of Set 9 | lasa
# Processing Record 30 of Set 9 | santa isabel do rio negro
# Processing Record 31 of Set 9 | tuensang
# Processing Record 32 of Set 9 | port hedland
# Processing Record 33 of Set 9 | alice town
# Processing Record 34 of Set 9 | porto novo
# Processing Record 35 of Set 9 | flin flon
# Processing Record 36 of Set 9 | iskateley
# Processing Record 37 of Set 9 | isla mujeres
# Processing Record 38 of Set 9 | tangjiazhuang
# Processing Record 39 of Set 9 | torbay
# Processing Record 40 of Set 9 | fukue
# Processing Record 41 of Set 9 | caronport
# Processing Record 42 of Set 9 | formosa do rio preto
# Processing Record 43 of Set 9 | petauke
# Processing Record 44 of Set 9 | sharanga
# Processing Record 45 of Set 9 | kieta
# Processing Record 46 of Set 9 | luderitz
# Processing Record 47 of Set 9 | sandnessjoen
# Processing Record 48 of Set 9 | portland
# Processing Record 49 of Set 9 | pokosnoye
# Processing Record 50 of Set 9 | palimbang
# Processing Record 1 of Set 10 | tilichiki
# Processing Record 2 of Set 10 | zhangye
# Processing Record 3 of Set 10 | belaya gora
# Processing Record 4 of Set 10 | nicoya
# Processing Record 5 of Set 10 | rzeszow
# Processing Record 6 of Set 10 | vila
# Processing Record 7 of Set 10 | seoul
# Processing Record 8 of Set 10 | agadez
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | camargo
# Processing Record 11 of Set 10 | bandarbeyla
# Processing Record 12 of Set 10 | zlynka
# Processing Record 13 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 10 | toppenish
# Processing Record 15 of Set 10 | bara
# Processing Record 16 of Set 10 | bolu
# Processing Record 17 of Set 10 | paracuru
# Processing Record 18 of Set 10 | naze
# Processing Record 19 of Set 10 | marrakesh
# Processing Record 20 of Set 10 | wanning
# Processing Record 21 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 22 of Set 10 | saint-georges
# Processing Record 23 of Set 10 | mount gambier
# Processing Record 24 of Set 10 | kiruna
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | pochutla
# Processing Record 27 of Set 10 | birjand
# Processing Record 28 of Set 10 | tuatapere
# Processing Record 29 of Set 10 | tadine
# Processing Record 30 of Set 10 | udachnyy
# Processing Record 31 of Set 10 | tessalit
# Processing Record 32 of Set 10 | nerang
# Processing Record 33 of Set 10 | bafoussam
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | boralday
# Processing Record 36 of Set 10 | navrongo
# Processing Record 37 of Set 10 | port hardy
# Processing Record 38 of Set 10 | kurilsk
# Processing Record 39 of Set 10 | santiago de cuba
# Processing Record 40 of Set 10 | talcahuano
# Processing Record 41 of Set 10 | waingapu
# Processing Record 42 of Set 10 | christchurch
# Processing Record 43 of Set 10 | acajutla
# Processing Record 44 of Set 10 | khrustalnyy
# City not found. Skipping...
# Processing Record 45 of Set 10 | korablino
# Processing Record 46 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 47 of Set 10 | tomatlan
# Processing Record 48 of Set 10 | trinidad
# Processing Record 49 of Set 10 | sokoto
# Processing Record 50 of Set 10 | lazaro cardenas
# Processing Record 1 of Set 11 | carman
# Processing Record 2 of Set 11 | santa cruz de la palma
# Processing Record 3 of Set 11 | imbituba
# Processing Record 4 of Set 11 | macon
# Processing Record 5 of Set 11 | pecos
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | khorramshahr
# Processing Record 8 of Set 11 | harwich
# Processing Record 9 of Set 11 | nantucket
# Processing Record 10 of Set 11 | aljezur
# Processing Record 11 of Set 11 | ishigaki
# Processing Record 12 of Set 11 | teguldet
# Processing Record 13 of Set 11 | pierre
# Processing Record 14 of Set 11 | ibra
# Processing Record 15 of Set 11 | mushie
# Processing Record 16 of Set 11 | awjilah
# Processing Record 17 of Set 11 | tongliao
# Processing Record 18 of Set 11 | de-kastri
# Processing Record 19 of Set 11 | blackwater
# Processing Record 20 of Set 11 | bagenalstown
# Processing Record 21 of Set 11 | guangyuan
# Processing Record 22 of Set 11 | tainan
# Processing Record 23 of Set 11 | yomou
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | baton rouge
# Processing Record 26 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 27 of Set 11 | menongue
# Processing Record 28 of Set 11 | teknaf
# Processing Record 29 of Set 11 | yevlax
# Processing Record 30 of Set 11 | staryy nadym
# Processing Record 31 of Set 11 | alofi
# Processing Record 32 of Set 11 | bac lieu
# Processing Record 33 of Set 11 | asau
# Processing Record 34 of Set 11 | beringovskiy
# Processing Record 35 of Set 11 | neustadt
# Processing Record 36 of Set 11 | yasothon
# Processing Record 37 of Set 11 | linfen
# Processing Record 38 of Set 11 | matagami
# Processing Record 39 of Set 11 | malie
# Processing Record 40 of Set 11 | oussouye
# Processing Record 41 of Set 11 | nizwa
# Processing Record 42 of Set 11 | grootfontein
# Processing Record 43 of Set 11 | novopokrovka
# Processing Record 44 of Set 11 | muswellbrook
# Processing Record 45 of Set 11 | bintulu
# Processing Record 46 of Set 11 | alexandria
# Processing Record 47 of Set 11 | birao
# Processing Record 48 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 11 | arrifes
# Processing Record 50 of Set 11 | vila velha
# Processing Record 1 of Set 12 | villazon
# Processing Record 2 of Set 12 | prince rupert
# Processing Record 3 of Set 12 | palasa
# Processing Record 4 of Set 12 | san vicente
# Processing Record 5 of Set 12 | auki
# Processing Record 6 of Set 12 | marawi
# Processing Record 7 of Set 12 | colares
# Processing Record 8 of Set 12 | samana
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | san angelo
# Processing Record 11 of Set 12 | koslan
# Processing Record 12 of Set 12 | sinop
# Processing Record 13 of Set 12 | dudinka
# Processing Record 14 of Set 12 | huarmey
# Processing Record 15 of Set 12 | chekhov
# Processing Record 16 of Set 12 | normandin
# Processing Record 17 of Set 12 | sabang
# Processing Record 18 of Set 12 | yerbogachen
# Processing Record 19 of Set 12 | san carlos de bariloche
# Processing Record 20 of Set 12 | lensk
# Processing Record 21 of Set 12 | sakakah
# Processing Record 22 of Set 12 | severodvinsk
# Processing Record 23 of Set 12 | villanueva
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | bratslav
# Processing Record 26 of Set 12 | kununurra
# Processing Record 27 of Set 12 | skjervoy
# Processing Record 28 of Set 12 | sao miguel do araguaia
# Processing Record 29 of Set 12 | shreveport
# Processing Record 30 of Set 12 | lesnoy
# Processing Record 31 of Set 12 | okha
# Processing Record 32 of Set 12 | cairns
# Processing Record 33 of Set 12 | mombaca
# Processing Record 34 of Set 12 | barra patuca
# Processing Record 35 of Set 12 | manokwari
# Processing Record 36 of Set 12 | fortuna
# Processing Record 37 of Set 12 | shetpe
# Processing Record 38 of Set 12 | villa sandino
# Processing Record 39 of Set 12 | olafsvik
# Processing Record 40 of Set 12 | yining
# Processing Record 41 of Set 12 | ondangwa
# Processing Record 42 of Set 12 | great bend
# Processing Record 43 of Set 12 | mhlambanyatsi
# Processing Record 44 of Set 12 | abilene
# Processing Record 45 of Set 12 | tornio
# Processing Record 46 of Set 12 | ariguani
# Processing Record 47 of Set 12 | samarai
# Processing Record 48 of Set 12 | chiang khong
# Processing Record 49 of Set 12 | baoding
# Processing Record 50 of Set 12 | manta
# Processing Record 1 of Set 13 | svetlaya
# Processing Record 2 of Set 13 | mopti
# Processing Record 3 of Set 13 | sayansk
# Processing Record 4 of Set 13 | poputnaya
# Processing Record 5 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 13 | lingao
# Processing Record 7 of Set 13 | zhuanghe
# Processing Record 8 of Set 13 | milan
# Processing Record 9 of Set 13 | port macquarie
# Processing Record 10 of Set 13 | vawkavysk
# Processing Record 11 of Set 13 | finschhafen
# Processing Record 12 of Set 13 | mizdah
# Processing Record 13 of Set 13 | vung tau
# Processing Record 14 of Set 13 | sioux lookout
# Processing Record 15 of Set 13 | jieshou
# Processing Record 16 of Set 13 | wazzan
# City not found. Skipping...
# Processing Record 17 of Set 13 | itoman
# Processing Record 18 of Set 13 | medicine hat
# Processing Record 19 of Set 13 | manyana
# Processing Record 20 of Set 13 | tautira
# Processing Record 21 of Set 13 | darlowo
# Processing Record 22 of Set 13 | berndorf
# Processing Record 23 of Set 13 | zaton
# Processing Record 24 of Set 13 | hovd
# Processing Record 25 of Set 13 | vestmannaeyjar
# Processing Record 26 of Set 13 | santa cruz cabralia
# Processing Record 27 of Set 13 | namatanai
# Processing Record 28 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 13 | noormarkku
# Processing Record 30 of Set 13 | mayo
# Processing Record 31 of Set 13 | balashov
# Processing Record 32 of Set 13 | hami
# Processing Record 33 of Set 13 | okhotsk
# Processing Record 34 of Set 13 | bambari
# Processing Record 35 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 13 | qaqortoq
# Processing Record 37 of Set 13 | aloleng
# Processing Record 38 of Set 13 | kahului
# Processing Record 39 of Set 13 | poya
# Processing Record 40 of Set 13 | muqui
# Processing Record 41 of Set 13 | bull savanna
# Processing Record 42 of Set 13 | redlands
# Processing Record 43 of Set 13 | moyo
# Processing Record 44 of Set 13 | lakselv
# Processing Record 45 of Set 13 | prince albert
# Processing Record 46 of Set 13 | mahon
# Processing Record 47 of Set 13 | hofn
# Processing Record 48 of Set 13 | eyl
# Processing Record 49 of Set 13 | champerico
# Processing Record 50 of Set 13 | leshukonskoye
# Processing Record 1 of Set 14 | murray bridge
# Processing Record 2 of Set 14 | dhangadhi
# Processing Record 3 of Set 14 | bam
# Processing Record 4 of Set 14 | fuyu
# Processing Record 5 of Set 14 | warwick
# Processing Record 6 of Set 14 | kerema
# Processing Record 7 of Set 14 | mwinilunga
# Processing Record 8 of Set 14 | broken hill
# Processing Record 9 of Set 14 | larsnes
# Processing Record 10 of Set 14 | ushtobe
# Processing Record 11 of Set 14 | ust-omchug
# Processing Record 12 of Set 14 | acapulco
# Processing Record 13 of Set 14 | san policarpo
# Processing Record 14 of Set 14 | peterhead
# Processing Record 15 of Set 14 | gardner
# Processing Record 16 of Set 14 | da nang
# Processing Record 17 of Set 14 | cap malheureux
# Processing Record 18 of Set 14 | semirom
# Processing Record 19 of Set 14 | zanjan
# Processing Record 20 of Set 14 | proddatur
# Processing Record 21 of Set 14 | stephenville
# Processing Record 22 of Set 14 | ferrandina
# Processing Record 23 of Set 14 | neiafu
# Processing Record 24 of Set 14 | orlik
# Processing Record 25 of Set 14 | yeppoon
# Processing Record 26 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 27 of Set 14 | canton
# Processing Record 28 of Set 14 | port dickson
# Processing Record 29 of Set 14 | surt
# Processing Record 30 of Set 14 | borovoy
# Processing Record 31 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 14 | concepcion de buenos aires
# Processing Record 33 of Set 14 | sturgeon falls
# Processing Record 34 of Set 14 | evensk
# Processing Record 35 of Set 14 | manaure
# Processing Record 36 of Set 14 | boden
# Processing Record 37 of Set 14 | ponta delgada
# Processing Record 38 of Set 14 | marzuq
# Processing Record 39 of Set 14 | muriwai beach
# Processing Record 40 of Set 14 | wageningen
# Processing Record 41 of Set 14 | gueugnon
# Processing Record 42 of Set 14 | teguise
# Processing Record 43 of Set 14 | verkhnyaya inta
# Processing Record 44 of Set 14 | qui nhon
# Processing Record 45 of Set 14 | maarianhamina
# Processing Record 46 of Set 14 | anchorage
# Processing Record 47 of Set 14 | katima mulilo
# Processing Record 48 of Set 14 | yingkou
# Processing Record 49 of Set 14 | kokstad
# Processing Record 50 of Set 14 | jacareacanga
# Processing Record 1 of Set 15 | cradock
# Processing Record 2 of Set 15 | sangar
# Processing Record 3 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 15 | conceicao das alagoas
# Processing Record 5 of Set 15 | sikasso
# Processing Record 6 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 7 of Set 15 | altagracia de orituco
# Processing Record 8 of Set 15 | satrikh
# Processing Record 9 of Set 15 | haimen
# Processing Record 10 of Set 15 | sankt johann im pongau
# Processing Record 11 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 15 | gurupi
# Processing Record 13 of Set 15 | villavicencio
# Processing Record 14 of Set 15 | panama city
# Processing Record 15 of Set 15 | denau
# City not found. Skipping...
# Processing Record 16 of Set 15 | qasigiannguit
# Processing Record 17 of Set 15 | odweyne
# Processing Record 18 of Set 15 | dalvik
# Processing Record 19 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 15 | urengoy
# Processing Record 21 of Set 15 | kolyvan
# Processing Record 22 of Set 15 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 23 of Set 15 | millington
# Processing Record 24 of Set 15 | oistins
# Processing Record 25 of Set 15 | padang
# Processing Record 26 of Set 15 | daru
# Processing Record 27 of Set 15 | yarmouth
# Processing Record 28 of Set 15 | gravdal
# Processing Record 29 of Set 15 | hidalgotitlan
# Processing Record 30 of Set 15 | batagay-alyta
# Processing Record 31 of Set 15 | zhirnov
# Processing Record 32 of Set 15 | caxito
# Processing Record 33 of Set 15 | ruidoso
# Processing Record 34 of Set 15 | carlisle
# Processing Record 35 of Set 15 | darhan
# Processing Record 36 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 15 | nouadhibou
# Processing Record 38 of Set 15 | warrnambool
# Processing Record 39 of Set 15 | odienne
# Processing Record 40 of Set 15 | mme
# City not found. Skipping...
# Processing Record 41 of Set 15 | kosonsoy
# Processing Record 42 of Set 15 | ternate
# Processing Record 43 of Set 15 | laukaa
# Processing Record 44 of Set 15 | chipurupalle
# Processing Record 45 of Set 15 | dawei
# Processing Record 46 of Set 15 | ende
# Processing Record 47 of Set 15 | kihei
# Processing Record 48 of Set 15 | valle hermoso
# Processing Record 49 of Set 15 | sohag
# Processing Record 50 of Set 15 | liverpool
# Processing Record 1 of Set 16 | dongsheng
# Processing Record 2 of Set 16 | sola
# Processing Record 3 of Set 16 | krasnoselkup
# Processing Record 4 of Set 16 | praia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nikolskoye      RU  59.7035   30.7861     55.29        90          87
# 1   Nizhniy Odes      RU  63.6445   54.8560     40.69        85         100
# 2    Mitsamiouli      KM -11.3847   43.2844     79.09        69          40
# 3          Pisco      PE -13.7000  -76.2167     66.02        77          40
# 4         Atuona      PF  -9.8000 -139.0333     78.31        70          84
# 5  Cockburn Town      TC  21.4612  -71.1419     85.96        66          40
# 6      Kilindoni      TZ  -7.9139   39.6668     77.04        73          45
# 7    New Norfolk      AU -42.7826  147.0587     54.90        67          98
# 8         Dikson      RU  73.5069   80.5464     48.94        77          98
# 9        Mataura      NZ -46.1927  168.8643     45.48        99          98
#
#    Wind Speed Current description
# 0        5.30     overcast clouds
# 1       11.72     overcast clouds
# 2        5.75    scattered clouds
# 3        9.22    scattered clouds
# 4       18.70          light rain
# 5       12.66    scattered clouds
# 6       12.77    scattered clouds
# 7       14.00     overcast clouds
# 8       17.29     overcast clouds
# 9        2.39     overcast clouds

# %%
# new_column_order = ["column2", "column4", "column1"]

#new_order= ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current description"]
city_data_df = city_data_df[new_order] 
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nikolskoye      RU  59.7035   30.7861     55.29        90          87
# 1   Nizhniy Odes      RU  63.6445   54.8560     40.69        85         100
# 2    Mitsamiouli      KM -11.3847   43.2844     79.09        69          40
# 3          Pisco      PE -13.7000  -76.2167     66.02        77          40
# 4         Atuona      PF  -9.8000 -139.0333     78.31        70          84
# 5  Cockburn Town      TC  21.4612  -71.1419     85.96        66          40
# 6      Kilindoni      TZ  -7.9139   39.6668     77.04        73          45
# 7    New Norfolk      AU -42.7826  147.0587     54.90        67          98
# 8         Dikson      RU  73.5069   80.5464     48.94        77          98
# 9        Mataura      NZ -46.1927  168.8643     45.48        99          98
#
#    Wind Speed Current description
# 0        5.30     overcast clouds
# 1       11.72     overcast clouds
# 2        5.75    scattered clouds
# 3        9.22    scattered clouds
# 4       18.70          light rain
# 5       12.66    scattered clouds
# 6       12.77    scattered clouds
# 7       14.00     overcast clouds
# 8       17.29     overcast clouds
# 9        2.39     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
