# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=yourkey
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
#url = "https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?"
# https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=yourkey

# %%
# Search for articles that mention granola
query = "Xbox"

# %%
# Build query URL
query_url = url + "q=" + query+ "&api-key=" + api_key
#query_url = url + "api-key=" + api_key

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles["response"]["docs"]]
pprint(articles_list)
# pprint(articles)
# Out:
# [{'_id': 'nyt://article/f5e13422-71c6-5355-8cf1-38c0e38a302d',
#   'abstract': 'Nice hardware? Check. Fair price? Check. Cool, exclusive games? '
#               'T.B.D.',
#   'byline': {'organization': None,
#              'original': 'By Brian X. Chen and Mike Isaac',
#              'person': [{'firstname': 'Brian',
#                          'lastname': 'Chen',
#                          'middlename': 'X.',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Mike',
#                          'lastname': 'Isaac',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': 'Tech Fix',
#                'main': 'Xbox Series X and S Review: Microsoft’s New Consoles '
#                        'Are a Good Value. Is That Enough?',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Computer and Video Games'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Xbox (Video Game System)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Computers and the Internet'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'PlayStation 4 (Video Game System)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 5,
#                 'value': 'Microsoft Corp'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': 'Sony Corporation'}],
#   'lead_paragraph': 'After seven years, the Microsoft Xbox and Sony '
#                     'PlayStation game consoles are getting big upgrades.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 337,
#                   'legacy': {'xlarge': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-articleLarge.jpg',
#                              'xlargeheight': 337,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 365,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-popup.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 300,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 240,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 203,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 333,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 337,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-slide.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 576,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-jumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-superJumbo.jpg',
#                   'width': 1080},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 590,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 379,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-master675.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 101,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-master180.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master315',
#                   'height': 177,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master315',
#                   'subtype': 'master315',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-master315.jpg',
#                   'width': 315},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master768',
#                   'subtype': 'master768',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-master768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2020/11/05/business/05techfix1/05techfix1-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-blogSmallThumb.jpg',
#                   'width': 50},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-thumbLarge.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare168',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare168',
#                   'subtype': 'smallSquare168',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-smallSquare168.jpg',
#                   'width': 168},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare252',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare252',
#                   'subtype': 'smallSquare252',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-smallSquare252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square320',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square320',
#                   'subtype': 'square320',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-square320.jpg',
#                   'width': 320},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'moth',
#                   'height': 151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'moth',
#                   'subtype': 'moth',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-moth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square640',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square640',
#                   'subtype': 'square640',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-square640-v2.jpg',
#                   'width': 640},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquare149',
#                   'height': 149,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquare149',
#                   'subtype': 'mediumSquare149',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumSquare149.jpg',
#                   'width': 149},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquareAt3X',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquareAt3X',
#                   'subtype': 'mediumSquareAt3X',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumSquareAt3X.jpg',
#                   'width': 608},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 263,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-sfSpan.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontal375',
#                   'height': 250,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontal375',
#                   'subtype': 'largeHorizontal375',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-largeHorizontal375.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontalJumbo',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontalJumbo',
#                   'subtype': 'largeHorizontalJumbo',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-largeHorizontalJumbo.jpg',
#                   'width': 912},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'horizontalMediumAt2X',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'horizontalMediumAt2X',
#                   'subtype': 'horizontalMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-horizontalMediumAt2X.jpg',
#                   'width': 912},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpLarge',
#                   'height': 287,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpLarge',
#                   'subtype': 'hpLarge',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-hpLarge.jpg',
#                   'width': 511},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen573',
#                   'height': 322,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen573',
#                   'subtype': 'largeWidescreen573',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-largeWidescreen573.jpg',
#                   'width': 573},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen1050',
#                   'height': 590,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen1050',
#                   'subtype': 'largeWidescreen1050',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-largeWidescreen1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbWide',
#                   'height': 126,
#                   'legacy': {'wide': 'images/2020/11/05/business/05techfix1/05techfix1-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-thumbWide.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoThumb',
#                   'subtype': 'videoThumb',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-videoThumb.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoLarge',
#                   'height': 507,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoLarge',
#                   'subtype': 'videoLarge',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-videoLarge.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo210',
#                   'height': 140,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo210',
#                   'subtype': 'mediumThreeByTwo210',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumThreeByTwo210.jpg',
#                   'width': 210},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo225',
#                   'subtype': 'mediumThreeByTwo225',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumThreeByTwo225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo440',
#                   'height': 293,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo440',
#                   'subtype': 'mediumThreeByTwo440',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumThreeByTwo440.jpg',
#                   'width': 440},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo252',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo252',
#                   'subtype': 'mediumThreeByTwo252',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumThreeByTwo252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo378',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo378',
#                   'subtype': 'mediumThreeByTwo378',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-mediumThreeByTwo378.jpg',
#                   'width': 378},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoLargeAt2X',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoLargeAt2X',
#                   'subtype': 'threeByTwoLargeAt2X',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-threeByTwoLargeAt2X.jpg',
#                   'width': 912},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoMediumAt2X',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoMediumAt2X',
#                   'subtype': 'threeByTwoMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-threeByTwoMediumAt2X.jpg',
#                   'width': 912},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoSmallAt2X',
#                   'height': 399,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoSmallAt2X',
#                   'subtype': 'threeByTwoSmallAt2X',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-threeByTwoSmallAt2X.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 107,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 92,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-hpSmall.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 85,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 99,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 211,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoHpMedium.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine600.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine540.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine390.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine310.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine96.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNine150.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-videoSixteenByNineJumbo1600.jpg',
#                   'width': 1080},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-miniMoth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-windowsTile336H.jpg',
#                   'width': 694},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 549,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-facebookJumbo.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/05techfix1-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mobileMasterAt3x',
#                   'height': 607,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mobileMasterAt3x',
#                   'subtype': 'mobileMasterAt3x',
#                   'type': 'image',
#                   'url': 'images/2020/11/05/business/05techfix1/merlin_179317002_bdab34db-887e-4d98-9d35-989134dda4af-mobileMasterAt3x.jpg',
#                   'width': 1080}],
#   'news_desk': 'Business',
#   'pub_date': '2020-11-05T14:00:11+0000',
#   'section_name': 'Technology',
#   'snippet': 'Nice hardware? Check. Fair price? Check. Cool, exclusive games? '
#              'T.B.D.',
#   'source': 'The New York Times',
#   'subsection_name': 'Personal Tech',
#   'type_of_material': 'Review',
#   'uri': 'nyt://article/f5e13422-71c6-5355-8cf1-38c0e38a302d',
#   'web_url': 'https://www.nytimes.com/2020/11/05/technology/personaltech/xbox-series-x-series-s-review.html',
#   'word_count': 1333},
#  {'_id': 'nyt://article/3ebd4a02-2d05-5b26-b6da-dba6ec3ea747',
#   'abstract': 'The company’s acquisition of ZeniMax Media puts it in a strong '
#               'position against Sony just weeks before the release of their '
#               'next generation of gaming consoles.',
#   'byline': {'organization': None,
#              'original': 'By Kellen Browning and Steve Lohr',
#              'person': [{'firstname': 'Kellen',
#                          'lastname': 'Browning',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Steve',
#                          'lastname': 'Lohr',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Microsoft Grabs Some of World’s Biggest Games in $7.5 '
#                        'Billion Deal',
#                'name': None,
#                'print_headline': 'Microsoft Lands Deal For ZeniMax, Buoying '
#                                  'Video Game Offerings',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Computer and Video Games'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Mergers, Acquisitions and Divestitures'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Software'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Xbox (Video Game System)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 5,
#                 'value': 'Microsoft Corp'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': 'ZeniMax Media'}],
#   'lead_paragraph': 'Microsoft landed a major blow in its decades-long battle '
#                     'with its video game industry rival Sony on Monday, '
#                     'announcing the $7.5 billion acquisition of a video game '
#                     'company that narrowed the gap between the two tech '
#                     'giants’ offerings.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 400,
#                   'legacy': {'xlarge': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-articleLarge.jpg',
#                              'xlargeheight': 400,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 433,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-popup.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 355,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 285,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 241,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 395,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-slide.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-jumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 1365,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-superJumbo.jpg',
#                   'width': 2048},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 700,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 450,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-master675.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 330,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2020/09/21/arts/21microsoft/merlin_156266604_d87be602-3c8d-4a80-ad82-b30e235166aa-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 120,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
# ...
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 118,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 263,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-sfSpan.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontal375',
#                   'height': 250,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontal375',
#                   'subtype': 'largeHorizontal375',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-largeHorizontal375.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpLarge',
#                   'height': 256,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpLarge',
#                   'subtype': 'hpLarge',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-hpLarge.jpg',
#                   'width': 511},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen573',
#                   'height': 287,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen573',
#                   'subtype': 'largeWidescreen573',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-largeWidescreen573.jpg',
#                   'width': 573},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-videoHpMedium.jpg',
#                   'width': 337},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-thumbLarge.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2013/06/22/business/20bits-xbox/20bits-xbox-blogSmallThumb.jpg',
#                   'width': 50}],
#   'news_desk': '',
#   'print_page': '7',
#   'print_section': 'B',
#   'pub_date': '2013-06-20T23:37:50+0000',
#   'section_name': 'Technology',
#   'snippet': 'Microsoft on Wednesday reversed a couple of controversial '
#              'policies about how its new Xbox One game console will operate, '
#              'both of which would probably have slammed the brakes on the used '
#              'games business. But that business is likely to fade away anyw...',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/b1ab931c-eb5e-537a-92b1-af04268e8733',
#   'web_url': 'https://bits.blogs.nytimes.com/2013/06/20/xbox-reversal-wont-stop-the-inevitable/',
#   'word_count': 436},
#  {'_id': 'nyt://article/ce619bd2-98cd-5621-8204-29f559140660',
#   'abstract': 'Like many young hipsters in Austin, Tex., Michael Burns wanted '
#               'to make it big in some creative field -- perhaps writing comedy '
#               'scripts in Hollywood. Instead, he wound up in a dead-end job, '
#               'managing a call center. To kill time, he made friends with a '
#               'group of equally clever and bored young men at the company '
#               "where he worked, and they'd sit around talking about their "
#               'shared passion: video games. Their favorite title was Halo, a '
#               'best-selling Xbox game in which players control armor-clad '
#               'soldiers as they wander through gorgeous coastal forests and '
#               'grim military bunkers and fight an army of lizardlike aliens. '
#               "Burns and his gang especially loved the ''team versus team'' "
#               'mode, which is like a digital version of paint ball: instead of '
#               'fighting aliens, players hook their Xboxes to the Internet, '
#               'then log on together in a single game, at which point they '
#               'assemble into two teams -- red-armored soldiers versus '
#               'blue-armored ones. Instead of shooting aliens, they try to '
#               'slaughter one another, using grenades, machine guns and death '
#               'rays. On evenings and weekends, Burns and his friends would '
#               "cluster around their TV's until the wee hours of the morning, "
#               "gleefully blowing one another to pieces.    ''Halo is like "
#               "crack,'' Burns recalls thinking. ''I could play it until I "
#               "die.''  ",
#   'byline': {'organization': None,
#              'original': 'By Clive Thompson',
#              'person': [{'firstname': 'Clive',
#                          'lastname': 'Thompson',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'The Xbox Auteurs',
#                'name': None,
#                'print_headline': 'The Xbox Auteurs',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'organizations',
#                 'rank': 1,
#                 'value': 'Microsoft Corporation'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'COPYRIGHTS'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'RECORDINGS (VIDEO)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'MOTION PICTURES'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 5,
#                 'value': 'Computer and Video Games'}],
#   'lead_paragraph': 'Like many young hipsters in Austin, Tex., Michael Burns '
#                     'wanted to make it big in some creative field -- perhaps '
#                     'writing comedy scripts in Hollywood. Instead, he wound up '
#                     'in a dead-end job, managing a call center. To kill time, '
#                     'he made friends with a group of equally clever and bored '
#                     "young men at the company where he worked, and they'd sit "
#                     'around talking about their shared passion: video games. '
#                     'Their favorite title was Halo, a best-selling Xbox game '
#                     'in which players control armor-clad soldiers as they '
#                     'wander through gorgeous coastal forests and grim military '
#                     'bunkers and fight an army of lizardlike aliens. Burns and '
#                     'his gang especially loved the "team versus team" mode, '
#                     'which is like a digital version of paint ball: instead of '
#                     'fighting aliens, players hook their Xboxes to the '
#                     'Internet, then log on together in a single game, at which '
#                     'point they assemble into two teams -- red-armored '
#                     'soldiers versus blue-armored ones. Instead of shooting '
#                     'aliens, they try to slaughter one another, using '
#                     'grenades, machine guns and death rays. On evenings and '
#                     'weekends, Burns and his friends would cluster around '
#                     "their TV's until the wee hours of the morning, gleefully "
#                     'blowing one another to pieces.',
#   'multimedia': [],
#   'news_desk': 'Magazine Desk',
#   'print_page': '21',
#   'print_section': '6',
#   'pub_date': '2005-08-07T05:00:00+0000',
#   'section_name': 'Magazine',
#   'snippet': 'Like many young hipsters in Austin, Tex., Michael Burns wanted '
#              'to make it big in some creative field -- perhaps writing comedy '
#              'scripts in Hollywood. Instead, he wound up in a dead-end job, '
#              'managing a call center. To kill time, he made friends with...',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/ce619bd2-98cd-5621-8204-29f559140660',
#   'web_url': 'https://www.nytimes.com/2005/08/07/magazine/the-xbox-auteurs.html',
#   'word_count': 4722},
#  {'_id': 'nyt://article/502f5b46-87bc-57e9-ba89-fd0dcb2b18bf',
#   'abstract': "Philips Electronics NV, Europe's No. 1 consumer-electronics "
#               'maker, said a unit of the company won an order from Microsoft '
#               'Corp. to supply the No. 1 software maker with a component for '
#               'its Xbox game console. Philips will make the digital video disk '
#               'drive f',
#   'byline': {'organization': None,
#              'original': 'By Victoria Shannon, International Herald Tribune',
#              'person': [{'firstname': 'Victoria',
#                          'lastname': 'Shannon',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'International',
#                          'lastname': 'Tribune',
#                          'middlename': 'Herald',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Tech Brief:PHILIPS IN XBOX',
#                'name': None,
#                'print_headline': 'Tech Brief:PHILIPS IN XBOX',
#                'seo': None,
#                'sub': None},
#   'keywords': [],
#   'lead_paragraph': "Philips Electronics NV, Europe's No. 1 "
#                     'consumer-electronics maker, said a unit of the company '
#                     'won an order from Microsoft Corp. to supply the No. 1 '
#                     'software maker with a component for its Xbox game '
#                     'console. Philips will make the digital video disk drive '
#                     'for Xbox, which goes on sale Nov. 8 in North America.',
#   'multimedia': [],
#   'news_desk': 'IHT News',
#   'pub_date': '2001-06-19T05:00:00+0000',
#   'section_name': 'Business Day',
#   'snippet': "Philips Electronics NV, Europe's No. 1 consumer-electronics "
#              'maker, said a unit of the company won an order from Microsoft '
#              'Corp. to supply the No. 1 software maker with a component for '
#              'its Xbox game console. Philips will make the digital video '
#              'disk...',
#   'source': 'International Herald Tribune',
#   'uri': 'nyt://article/502f5b46-87bc-57e9-ba89-fd0dcb2b18bf',
#   'web_url': 'https://www.nytimes.com/2001/06/19/business/worldbusiness/IHT-tech-briefphilips-in-xbox.html',
#   'word_count': 312},
#  {'_id': 'nyt://article/07cedda9-a8af-5b94-b62b-f3999396bb1e',
#   'abstract': 'Softbank Commerce Corp. and Happinet Corp. will spearhead sales '
#               "of Microsoft Corp.'s Xbox game console in Japan, Microsoft's "
#               'Japan unit said.',
#   'byline': {'organization': None,
#              'original': 'By James Connell, International Herald Tribune',
#              'person': [{'firstname': 'James',
#                          'lastname': 'Connell',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'International',
#                          'lastname': 'Tribune',
#                          'middlename': 'Herald',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Tech Brief:SELLING XBOX',
#                'name': None,
#                'print_headline': 'Tech Brief:SELLING XBOX',
#                'seo': None,
#                'sub': None},
#   'keywords': [],
#   'lead_paragraph': 'Softbank Commerce Corp. and Happinet Corp. will spearhead '
#                     "sales of Microsoft Corp.'s Xbox game console in Japan, "
#                     "Microsoft's Japan unit said.",
#   'multimedia': [],
#   'news_desk': 'IHT News',
#   'pub_date': '2001-02-15T05:00:00+0000',
#   'section_name': 'Business Day',
#   'snippet': '',
#   'source': 'International Herald Tribune',
#   'uri': 'nyt://article/07cedda9-a8af-5b94-b62b-f3999396bb1e',
#   'web_url': 'https://www.nytimes.com/2001/02/15/business/worldbusiness/IHT-tech-briefselling-xbox.html',
#   'word_count': 151}]

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your Reading List
# https://www.nytimes.com/2020/11/05/technology/personaltech/xbox-series-x-series-s-review.html
# https://www.nytimes.com/2020/09/21/technology/microsoft-zenimax-video-game-deal.html
# https://www.nytimes.com/2020/09/15/technology/xbox-series-x-playstation-5.html
# https://www.nytimes.com/2020/08/24/sports/basketball/wnba-dallas-wings-allisha-gray.html
# https://www.nytimes.com/2005/12/18/books/review/generation-xbox.html
# https://bits.blogs.nytimes.com/2007/10/19/the-halo-over-xbox/
# https://bits.blogs.nytimes.com/2013/06/20/xbox-reversal-wont-stop-the-inevitable/
# https://www.nytimes.com/2005/08/07/magazine/the-xbox-auteurs.html
# https://www.nytimes.com/2001/06/19/business/worldbusiness/IHT-tech-briefphilips-in-xbox.html
# https://www.nytimes.com/2001/02/15/business/worldbusiness/IHT-tech-briefselling-xbox.html
