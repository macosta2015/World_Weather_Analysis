# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
#from config import weather_api_key
weather_api_key = "c334a28706460f469f090fde04b34da0"
# Import the datetime module from the datetime library.
from datetime import datetime
import json
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather
print(city_weather["weather"][0]["description"])
# Out:
# broken clouds

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | harindanga
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | yinchuan
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | san matias
# Processing Record 14 of Set 1 | harper
# Processing Record 15 of Set 1 | neuquen
# Processing Record 16 of Set 1 | pak thong chai
# Processing Record 17 of Set 1 | nanortalik
# Processing Record 18 of Set 1 | ambon
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | dunedin
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | coihaique
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | sitka
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | necochea
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | merrill
# Processing Record 31 of Set 1 | imbituba
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | fukue
# Processing Record 35 of Set 1 | quatre cocos
# Processing Record 36 of Set 1 | sanmenxia
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | aripuana
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | yashan
# Processing Record 43 of Set 1 | kolyvan
# Processing Record 44 of Set 1 | grindavik
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | port hueneme
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | bam
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | nola
# Processing Record 3 of Set 2 | samarai
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | isangel
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | talara
# Processing Record 8 of Set 2 | yatou
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | tsiroanomandidy
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | najran
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | adzope
# Processing Record 17 of Set 2 | takaungu
# Processing Record 18 of Set 2 | dunhua
# Processing Record 19 of Set 2 | novoderevyankovskaya
# Processing Record 20 of Set 2 | tarata
# Processing Record 21 of Set 2 | katangli
# Processing Record 22 of Set 2 | buzmeyin
# Processing Record 23 of Set 2 | havre-saint-pierre
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | adre
# Processing Record 26 of Set 2 | mountrath
# Processing Record 27 of Set 2 | arica
# Processing Record 28 of Set 2 | kaduqli
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | guerrero negro
# Processing Record 32 of Set 2 | dzerzhinsk
# Processing Record 33 of Set 2 | porto de moz
# Processing Record 34 of Set 2 | auki
# Processing Record 35 of Set 2 | cabedelo
# Processing Record 36 of Set 2 | leningradskiy
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | san quintin
# Processing Record 40 of Set 2 | guelengdeng
# City not found. Skipping...
# Processing Record 41 of Set 2 | faanui
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | moron
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | lervik
# Processing Record 48 of Set 2 | beringovskiy
# Processing Record 49 of Set 2 | kavaratti
# Processing Record 50 of Set 2 | cape canaveral
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | ziro
# Processing Record 3 of Set 3 | rio gallegos
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | husavik
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 3 | korla
# Processing Record 8 of Set 3 | pozo colorado
# Processing Record 9 of Set 3 | boguchany
# Processing Record 10 of Set 3 | preobrazheniye
# Processing Record 11 of Set 3 | mackay
# Processing Record 12 of Set 3 | luan
# Processing Record 13 of Set 3 | impfondo
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | gorontalo
# Processing Record 17 of Set 3 | gizo
# Processing Record 18 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 3 | patacamaya
# Processing Record 20 of Set 3 | kloulklubed
# Processing Record 21 of Set 3 | masumbwe
# Processing Record 22 of Set 3 | waipawa
# Processing Record 23 of Set 3 | vila franca do campo
# Processing Record 24 of Set 3 | waingapu
# Processing Record 25 of Set 3 | kenai
# Processing Record 26 of Set 3 | whitehorse
# Processing Record 27 of Set 3 | ruteng
# Processing Record 28 of Set 3 | nikolsk
# Processing Record 29 of Set 3 | komsomolskiy
# Processing Record 30 of Set 3 | baneh
# Processing Record 31 of Set 3 | cururupu
# Processing Record 32 of Set 3 | folkestone
# Processing Record 33 of Set 3 | macas
# Processing Record 34 of Set 3 | sao miguel
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | mikkeli
# Processing Record 39 of Set 3 | castro
# Processing Record 40 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 3 | sayyan
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | caravelas
# Processing Record 44 of Set 3 | hofn
# Processing Record 45 of Set 3 | beloha
# Processing Record 46 of Set 3 | egvekinot
# Processing Record 47 of Set 3 | chumikan
# Processing Record 48 of Set 3 | mendeleyevo
# Processing Record 49 of Set 3 | luena
# Processing Record 50 of Set 3 | iberia
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | tongsa
# City not found. Skipping...
# Processing Record 4 of Set 4 | bonoua
# Processing Record 5 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 4 | kulhudhuffushi
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | victoria
# Processing Record 9 of Set 4 | chifeng
# Processing Record 10 of Set 4 | sao jose da coroa grande
# Processing Record 11 of Set 4 | atuona
# Processing Record 12 of Set 4 | agadez
# Processing Record 13 of Set 4 | bara
# Processing Record 14 of Set 4 | yuancheng
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | eureka
# Processing Record 17 of Set 4 | gamba
# Processing Record 18 of Set 4 | paita
# Processing Record 19 of Set 4 | ouallam
# Processing Record 20 of Set 4 | geraldton
# Processing Record 21 of Set 4 | grandview
# Processing Record 22 of Set 4 | pacific grove
# Processing Record 23 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 4 | santo augusto
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | huarmey
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | seoul
# Processing Record 29 of Set 4 | tinos
# Processing Record 30 of Set 4 | jiaozhou
# Processing Record 31 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 4 | ulaangom
# Processing Record 33 of Set 4 | ilo
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | port alfred
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | sinjah
# City not found. Skipping...
# Processing Record 38 of Set 4 | kahului
# Processing Record 39 of Set 4 | ketchikan
# Processing Record 40 of Set 4 | nuuk
# Processing Record 41 of Set 4 | andenes
# Processing Record 42 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 43 of Set 4 | virtsu
# Processing Record 44 of Set 4 | kamenka
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | guangyuan
# Processing Record 48 of Set 4 | sokoni
# Processing Record 49 of Set 4 | santa cecilia
# Processing Record 50 of Set 4 | shizunai
# Processing Record 1 of Set 5 | mantua
# Processing Record 2 of Set 5 | evensk
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | coahuayana
# Processing Record 5 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | angoram
# Processing Record 8 of Set 5 | richards bay
# Processing Record 9 of Set 5 | baykit
# Processing Record 10 of Set 5 | birao
# Processing Record 11 of Set 5 | romny
# Processing Record 12 of Set 5 | paiho
# City not found. Skipping...
# Processing Record 13 of Set 5 | mogadishu
# Processing Record 14 of Set 5 | san andres
# Processing Record 15 of Set 5 | marevo
# Processing Record 16 of Set 5 | the valley
# Processing Record 17 of Set 5 | polson
# Processing Record 18 of Set 5 | keti bandar
# Processing Record 19 of Set 5 | broome
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | touros
# Processing Record 23 of Set 5 | orgun
# City not found. Skipping...
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | talaya
# Processing Record 26 of Set 5 | fort nelson
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | kingston
# Processing Record 29 of Set 5 | pathein
# Processing Record 30 of Set 5 | haines junction
# Processing Record 31 of Set 5 | vestmannaeyjar
# Processing Record 32 of Set 5 | albania
# Processing Record 33 of Set 5 | san onofre
# Processing Record 34 of Set 5 | agva
# City not found. Skipping...
# Processing Record 35 of Set 5 | darab
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | hobyo
# Processing Record 38 of Set 5 | tabuk
# Processing Record 39 of Set 5 | aosta
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | eskil
# Processing Record 42 of Set 5 | aquidauana
# Processing Record 43 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 5 | mar del plata
# Processing Record 45 of Set 5 | oussouye
# Processing Record 46 of Set 5 | srandakan
# Processing Record 47 of Set 5 | lompoc
# Processing Record 48 of Set 5 | pringsewu
# Processing Record 49 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | san patricio
# Processing Record 2 of Set 6 | alappuzha
# Processing Record 3 of Set 6 | esna
# Processing Record 4 of Set 6 | caridad
# Processing Record 5 of Set 6 | lisburn
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | borujan
# City not found. Skipping...
# Processing Record 8 of Set 6 | barrow
# Processing Record 9 of Set 6 | mitsamiouli
# Processing Record 10 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 6 | cap-aux-meules
# Processing Record 12 of Set 6 | mehamn
# Processing Record 13 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 6 | palaikastron
# Processing Record 15 of Set 6 | asau
# Processing Record 16 of Set 6 | cap malheureux
# Processing Record 17 of Set 6 | khatanga
# Processing Record 18 of Set 6 | northam
# Processing Record 19 of Set 6 | aswan
# Processing Record 20 of Set 6 | morgan city
# Processing Record 21 of Set 6 | rietavas
# Processing Record 22 of Set 6 | plyussa
# Processing Record 23 of Set 6 | aliwal north
# Processing Record 24 of Set 6 | yagodnoye
# Processing Record 25 of Set 6 | havelock
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | pudukkottai
# Processing Record 28 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 6 | barra do garcas
# Processing Record 31 of Set 6 | vitim
# Processing Record 32 of Set 6 | nabire
# Processing Record 33 of Set 6 | bani walid
# Processing Record 34 of Set 6 | poum
# Processing Record 35 of Set 6 | khandbari
# Processing Record 36 of Set 6 | lucea
# Processing Record 37 of Set 6 | chuy
# Processing Record 38 of Set 6 | lyndon
# Processing Record 39 of Set 6 | longyearbyen
# Processing Record 40 of Set 6 | karratha
# Processing Record 41 of Set 6 | manaus
# Processing Record 42 of Set 6 | neiafu
# Processing Record 43 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 6 | riyadh
# Processing Record 45 of Set 6 | hornepayne
# Processing Record 46 of Set 6 | lavrentiya
# Processing Record 47 of Set 6 | sabha
# Processing Record 48 of Set 6 | vanimo
# Processing Record 49 of Set 6 | provideniya
# Processing Record 50 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | montijo
# Processing Record 3 of Set 7 | chokurdakh
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | huanren
# Processing Record 6 of Set 7 | turkmenabat
# Processing Record 7 of Set 7 | miri
# Processing Record 8 of Set 7 | sabang
# Processing Record 9 of Set 7 | guiratinga
# Processing Record 10 of Set 7 | pilar
# Processing Record 11 of Set 7 | vershino-darasunskiy
# Processing Record 12 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 7 | saint anthony
# Processing Record 15 of Set 7 | merritt island
# Processing Record 16 of Set 7 | alta floresta
# Processing Record 17 of Set 7 | ewa beach
# Processing Record 18 of Set 7 | saskylakh
# Processing Record 19 of Set 7 | bihoro
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | qurayyat
# Processing Record 22 of Set 7 | micheweni
# Processing Record 23 of Set 7 | cayenne
# Processing Record 24 of Set 7 | usinsk
# Processing Record 25 of Set 7 | timbiras
# Processing Record 26 of Set 7 | lindi
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | obihiro
# Processing Record 29 of Set 7 | high level
# Processing Record 30 of Set 7 | dakar
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | kwinana
# Processing Record 33 of Set 7 | nynashamn
# Processing Record 34 of Set 7 | muros
# Processing Record 35 of Set 7 | paamiut
# Processing Record 36 of Set 7 | upernavik
# Processing Record 37 of Set 7 | ponta delgada
# Processing Record 38 of Set 7 | mossendjo
# Processing Record 39 of Set 7 | winder
# Processing Record 40 of Set 7 | hami
# Processing Record 41 of Set 7 | port lincoln
# Processing Record 42 of Set 7 | tautira
# Processing Record 43 of Set 7 | tricase
# Processing Record 44 of Set 7 | evinayong
# Processing Record 45 of Set 7 | arman
# Processing Record 46 of Set 7 | narbonne
# Processing Record 47 of Set 7 | kommunisticheskiy
# Processing Record 48 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 7 | hammerfest
# Processing Record 1 of Set 8 | killybegs
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | adamas
# Processing Record 4 of Set 8 | sumkino
# Processing Record 5 of Set 8 | sibolga
# Processing Record 6 of Set 8 | sarakhs
# Processing Record 7 of Set 8 | namatanai
# Processing Record 8 of Set 8 | kot addu
# Processing Record 9 of Set 8 | buala
# Processing Record 10 of Set 8 | port augusta
# Processing Record 11 of Set 8 | alawalpur
# Processing Record 12 of Set 8 | dalvik
# Processing Record 13 of Set 8 | brae
# Processing Record 14 of Set 8 | ostrovnoy
# Processing Record 15 of Set 8 | cherskiy
# Processing Record 16 of Set 8 | huntsville
# Processing Record 17 of Set 8 | narsaq
# Processing Record 18 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 19 of Set 8 | sarhari
# Processing Record 20 of Set 8 | rudnichnyy
# Processing Record 21 of Set 8 | chivay
# Processing Record 22 of Set 8 | sumbe
# Processing Record 23 of Set 8 | yurla
# Processing Record 24 of Set 8 | malanje
# Processing Record 25 of Set 8 | phanat nikhom
# Processing Record 26 of Set 8 | bandarbeyla
# Processing Record 27 of Set 8 | carbonear
# Processing Record 28 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 8 | palu
# Processing Record 30 of Set 8 | bull savanna
# Processing Record 31 of Set 8 | abha
# Processing Record 32 of Set 8 | tongliao
# Processing Record 33 of Set 8 | ulagan
# Processing Record 34 of Set 8 | muramatsu
# Processing Record 35 of Set 8 | kruisfontein
# Processing Record 36 of Set 8 | ribeira grande
# Processing Record 37 of Set 8 | kyzyl-suu
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | new bern
# Processing Record 41 of Set 8 | tocopilla
# Processing Record 42 of Set 8 | fuling
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | surt
# Processing Record 45 of Set 8 | chase
# Processing Record 46 of Set 8 | alvaraes
# Processing Record 47 of Set 8 | porto novo
# Processing Record 48 of Set 8 | gornopravdinsk
# Processing Record 49 of Set 8 | molteno
# Processing Record 50 of Set 8 | vaitape
# Processing Record 1 of Set 9 | coracora
# Processing Record 2 of Set 9 | burica
# City not found. Skipping...
# Processing Record 3 of Set 9 | labuhan
# Processing Record 4 of Set 9 | gualeguay
# Processing Record 5 of Set 9 | port stanley
# Processing Record 6 of Set 9 | phan thiet
# Processing Record 7 of Set 9 | chuguyevka
# Processing Record 8 of Set 9 | gorkovskoye
# City not found. Skipping...
# Processing Record 9 of Set 9 | palana
# Processing Record 10 of Set 9 | sojitra
# Processing Record 11 of Set 9 | mitu
# Processing Record 12 of Set 9 | sangre grande
# Processing Record 13 of Set 9 | vao
# Processing Record 14 of Set 9 | marawi
# Processing Record 15 of Set 9 | kavieng
# Processing Record 16 of Set 9 | flums
# Processing Record 17 of Set 9 | ayan
# Processing Record 18 of Set 9 | kaitangata
# Processing Record 19 of Set 9 | ndola
# Processing Record 20 of Set 9 | vapnyarka
# Processing Record 21 of Set 9 | praia da vitoria
# Processing Record 22 of Set 9 | inta
# Processing Record 23 of Set 9 | nioro
# Processing Record 24 of Set 9 | suchil
# Processing Record 25 of Set 9 | katsuura
# Processing Record 26 of Set 9 | neuruppin
# Processing Record 27 of Set 9 | ucluelet
# Processing Record 28 of Set 9 | lakatoro
# Processing Record 29 of Set 9 | ugoofaaru
# Processing Record 30 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 9 | wuxue
# Processing Record 32 of Set 9 | saint-leu
# Processing Record 33 of Set 9 | laizhou
# Processing Record 34 of Set 9 | muskegon
# Processing Record 35 of Set 9 | yerbogachen
# Processing Record 36 of Set 9 | upata
# Processing Record 37 of Set 9 | ust-tsilma
# Processing Record 38 of Set 9 | brightwater
# Processing Record 39 of Set 9 | opuwo
# Processing Record 40 of Set 9 | tsentralnyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | phetchabun
# Processing Record 42 of Set 9 | saquarema
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | la asuncion
# Processing Record 45 of Set 9 | ishinomaki
# Processing Record 46 of Set 9 | tianpeng
# Processing Record 47 of Set 9 | valley station
# Processing Record 48 of Set 9 | darhan
# Processing Record 49 of Set 9 | mudon
# Processing Record 50 of Set 9 | bathsheba
# Processing Record 1 of Set 10 | oyama
# Processing Record 2 of Set 10 | pital
# Processing Record 3 of Set 10 | olinda
# Processing Record 4 of Set 10 | sri aman
# Processing Record 5 of Set 10 | iracoubo
# Processing Record 6 of Set 10 | harlingen
# Processing Record 7 of Set 10 | sena madureira
# Processing Record 8 of Set 10 | ostersund
# Processing Record 9 of Set 10 | kangaatsiaq
# Processing Record 10 of Set 10 | sechura
# Processing Record 11 of Set 10 | aykhal
# Processing Record 12 of Set 10 | tura
# Processing Record 13 of Set 10 | okha
# Processing Record 14 of Set 10 | port macquarie
# Processing Record 15 of Set 10 | jalu
# Processing Record 16 of Set 10 | daru
# Processing Record 17 of Set 10 | burnie
# Processing Record 18 of Set 10 | praia
# Processing Record 19 of Set 10 | atar
# Processing Record 20 of Set 10 | poronaysk
# Processing Record 21 of Set 10 | balad
# Processing Record 22 of Set 10 | ejutla de crespo
# Processing Record 23 of Set 10 | jinxiang
# Processing Record 24 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | kosh-agach
# Processing Record 26 of Set 10 | zhigansk
# Processing Record 27 of Set 10 | kota
# Processing Record 28 of Set 10 | la ronge
# Processing Record 29 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 10 | theologos
# City not found. Skipping...
# Processing Record 31 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 10 | pevek
# Processing Record 33 of Set 10 | twentynine palms
# Processing Record 34 of Set 10 | san francisco
# Processing Record 35 of Set 10 | sorland
# Processing Record 36 of Set 10 | inhambane
# Processing Record 37 of Set 10 | conakry
# Processing Record 38 of Set 10 | chastyye
# Processing Record 39 of Set 10 | monywa
# Processing Record 40 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 10 | novolvovsk
# City not found. Skipping...
# Processing Record 42 of Set 10 | okulovka
# Processing Record 43 of Set 10 | antalaha
# Processing Record 44 of Set 10 | weihai
# Processing Record 45 of Set 10 | grand baie
# Processing Record 46 of Set 10 | tessalit
# Processing Record 47 of Set 10 | plettenberg bay
# Processing Record 48 of Set 10 | dolores
# Processing Record 49 of Set 10 | la tuque
# Processing Record 50 of Set 10 | sao jose de ribamar
# Processing Record 1 of Set 11 | namibe
# Processing Record 2 of Set 11 | marathon
# Processing Record 3 of Set 11 | berlevag
# Processing Record 4 of Set 11 | astaneh-ye ashrafiyeh
# Processing Record 5 of Set 11 | tuatapere
# Processing Record 6 of Set 11 | biak
# Processing Record 7 of Set 11 | northglenn
# Processing Record 8 of Set 11 | bluffton
# Processing Record 9 of Set 11 | tazovskiy
# Processing Record 10 of Set 11 | solano
# Processing Record 11 of Set 11 | awjilah
# Processing Record 12 of Set 11 | kaputa
# Processing Record 13 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 11 | rio grande
# Processing Record 15 of Set 11 | cortland
# Processing Record 16 of Set 11 | solnechnyy
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | lazaro cardenas
# Processing Record 19 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 11 | batagay-alyta
# Processing Record 21 of Set 11 | hargeysa
# Processing Record 22 of Set 11 | chicama
# Processing Record 23 of Set 11 | bocas del toro
# Processing Record 24 of Set 11 | xinxiang
# Processing Record 25 of Set 11 | honavar
# Processing Record 26 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 11 | maniitsoq
# Processing Record 28 of Set 11 | dembi dolo
# Processing Record 29 of Set 11 | vostok
# Processing Record 30 of Set 11 | ormond beach
# Processing Record 31 of Set 11 | winnemucca
# Processing Record 32 of Set 11 | puerto carreno
# Processing Record 33 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 11 | voh
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | maceio
# Processing Record 37 of Set 11 | sept-iles
# Processing Record 38 of Set 11 | san luis
# Processing Record 39 of Set 11 | correntina
# Processing Record 40 of Set 11 | clyde
# Processing Record 41 of Set 11 | yuryevets
# Processing Record 42 of Set 11 | teya
# Processing Record 43 of Set 11 | montrose
# Processing Record 44 of Set 11 | port-gentil
# Processing Record 45 of Set 11 | shubarshi
# Processing Record 46 of Set 11 | qui nhon
# Processing Record 47 of Set 11 | sakakah
# Processing Record 48 of Set 11 | severomuysk
# Processing Record 49 of Set 11 | padang
# Processing Record 50 of Set 11 | christchurch
# Processing Record 1 of Set 12 | ilembula
# Processing Record 2 of Set 12 | tuy hoa
# Processing Record 3 of Set 12 | anchorage
# Processing Record 4 of Set 12 | codrington
# Processing Record 5 of Set 12 | pandamatenga
# Processing Record 6 of Set 12 | west fargo
# Processing Record 7 of Set 12 | tacuati
# Processing Record 8 of Set 12 | adrar
# Processing Record 9 of Set 12 | trinidad
# Processing Record 10 of Set 12 | kayalpattinam
# Processing Record 11 of Set 12 | zarinsk
# Processing Record 12 of Set 12 | cairns
# Processing Record 13 of Set 12 | bristol
# Processing Record 14 of Set 12 | jurado
# Processing Record 15 of Set 12 | dudinka
# Processing Record 16 of Set 12 | parfino
# Processing Record 17 of Set 12 | lebedinyy
# Processing Record 18 of Set 12 | arona
# Processing Record 19 of Set 12 | lubao
# Processing Record 20 of Set 12 | melville
# Processing Record 21 of Set 12 | moussoro
# Processing Record 22 of Set 12 | tarabuco
# Processing Record 23 of Set 12 | gondanglegi
# Processing Record 24 of Set 12 | south lake tahoe
# Processing Record 25 of Set 12 | mattru
# Processing Record 26 of Set 12 | jizan
# Processing Record 27 of Set 12 | verkhnyaya inta
# Processing Record 28 of Set 12 | omboue
# Processing Record 29 of Set 12 | nantucket
# Processing Record 30 of Set 12 | qasigiannguit
# Processing Record 31 of Set 12 | yeehaw junction
# City not found. Skipping...
# Processing Record 32 of Set 12 | ostrov
# Processing Record 33 of Set 12 | lethem
# Processing Record 34 of Set 12 | matay
# Processing Record 35 of Set 12 | bereda
# Processing Record 36 of Set 12 | katherine
# Processing Record 37 of Set 12 | flinders
# Processing Record 38 of Set 12 | ocos
# Processing Record 39 of Set 12 | tomatlan
# Processing Record 40 of Set 12 | udachnyy
# Processing Record 41 of Set 12 | lima
# Processing Record 42 of Set 12 | saint-augustin
# Processing Record 43 of Set 12 | jiamusi
# Processing Record 44 of Set 12 | ville-marie
# Processing Record 45 of Set 12 | yulara
# Processing Record 46 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 12 | linjiang
# Processing Record 48 of Set 12 | jiexiu
# Processing Record 49 of Set 12 | bilma
# Processing Record 50 of Set 12 | luderitz
# Processing Record 1 of Set 13 | mgachi
# Processing Record 2 of Set 13 | akyab
# Processing Record 3 of Set 13 | broken hill
# Processing Record 4 of Set 13 | iwanai
# Processing Record 5 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 6 of Set 13 | linares
# Processing Record 7 of Set 13 | carnarvon
# Processing Record 8 of Set 13 | jaguaruna
# Processing Record 9 of Set 13 | nishihara
# Processing Record 10 of Set 13 | mahanoro
# Processing Record 11 of Set 13 | gopamau
# Processing Record 12 of Set 13 | sioux lookout
# Processing Record 13 of Set 13 | mandalgovi
# Processing Record 14 of Set 13 | havoysund
# Processing Record 15 of Set 13 | alice springs
# Processing Record 16 of Set 13 | antofagasta
# Processing Record 17 of Set 13 | jumla
# Processing Record 18 of Set 13 | osoyoos
# Processing Record 19 of Set 13 | mangrol
# Processing Record 20 of Set 13 | kashi
# Processing Record 21 of Set 13 | ambilobe
# Processing Record 22 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 13 | camacha
# Processing Record 24 of Set 13 | muyezerskiy
# Processing Record 25 of Set 13 | honiara
# Processing Record 26 of Set 13 | ndele
# Processing Record 27 of Set 13 | tres arroyos
# Processing Record 28 of Set 13 | saint george
# Processing Record 29 of Set 13 | pangody
# Processing Record 30 of Set 13 | rognan
# Processing Record 31 of Set 13 | katha
# City not found. Skipping...
# Processing Record 32 of Set 13 | swindon
# Processing Record 33 of Set 13 | bitung
# Processing Record 34 of Set 13 | oranzherei
# Processing Record 35 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 36 of Set 13 | talavera
# Processing Record 37 of Set 13 | hamilton
# Processing Record 38 of Set 13 | steamboat springs
# Processing Record 39 of Set 13 | slave lake
# Processing Record 40 of Set 13 | amberley
# Processing Record 41 of Set 13 | oktyabrskoye
# Processing Record 42 of Set 13 | pljevlja
# Processing Record 43 of Set 13 | larap
# Processing Record 44 of Set 13 | panaba
# Processing Record 45 of Set 13 | rudbar
# Processing Record 46 of Set 13 | yumen
# Processing Record 47 of Set 13 | arlit
# Processing Record 48 of Set 13 | aksarka
# Processing Record 49 of Set 13 | toora-khem
# Processing Record 50 of Set 13 | talcahuano
# Processing Record 1 of Set 14 | ouesso
# Processing Record 2 of Set 14 | mareeba
# Processing Record 3 of Set 14 | turukhansk
# Processing Record 4 of Set 14 | pustoshka
# Processing Record 5 of Set 14 | sheridan
# Processing Record 6 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 14 | kalianget
# Processing Record 8 of Set 14 | maebaru
# Processing Record 9 of Set 14 | gigmoto
# Processing Record 10 of Set 14 | nasrullaganj
# City not found. Skipping...
# Processing Record 11 of Set 14 | san jose
# Processing Record 12 of Set 14 | yar-sale
# Processing Record 13 of Set 14 | caconda
# Processing Record 14 of Set 14 | wewak
# Processing Record 15 of Set 14 | lata
# Processing Record 16 of Set 14 | kieta
# Processing Record 17 of Set 14 | sandwick
# Processing Record 18 of Set 14 | kapit
# Processing Record 19 of Set 14 | maragogi
# Processing Record 20 of Set 14 | isiro
# Processing Record 21 of Set 14 | sembe
# Processing Record 22 of Set 14 | simao
# Processing Record 23 of Set 14 | balakirevo
# Processing Record 24 of Set 14 | kharovsk
# Processing Record 25 of Set 14 | cabinda
# Processing Record 26 of Set 14 | tiarei
# Processing Record 27 of Set 14 | kutum
# Processing Record 28 of Set 14 | balclutha
# Processing Record 29 of Set 14 | samus
# Processing Record 30 of Set 14 | liminangcong
# City not found. Skipping...
# Processing Record 31 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 35 of Set 14 | te anau
# Processing Record 36 of Set 14 | aleksandrovskiy zavod
# Processing Record 37 of Set 14 | nouadhibou
# Processing Record 38 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 39 of Set 14 | vardo
# Processing Record 40 of Set 14 | comodoro rivadavia
# Processing Record 41 of Set 14 | santa fe
# Processing Record 42 of Set 14 | xuddur
# Processing Record 43 of Set 14 | suao
# City not found. Skipping...
# Processing Record 44 of Set 14 | wufeng
# Processing Record 45 of Set 14 | sakaiminato
# Processing Record 46 of Set 14 | caceres
# Processing Record 47 of Set 14 | akhmim
# Processing Record 48 of Set 14 | karasjok
# Processing Record 49 of Set 14 | rosarito
# Processing Record 50 of Set 14 | okato
# Processing Record 1 of Set 15 | galle
# Processing Record 2 of Set 15 | rawson
# Processing Record 3 of Set 15 | berdigestyakh
# Processing Record 4 of Set 15 | tsabong
# Processing Record 5 of Set 15 | champerico
# Processing Record 6 of Set 15 | marsa matruh
# Processing Record 7 of Set 15 | hambantota
# Processing Record 8 of Set 15 | belebey
# Processing Record 9 of Set 15 | esso
# Processing Record 10 of Set 15 | nicolas bravo
# Processing Record 11 of Set 15 | mildura
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | santa maria da vitoria
# Processing Record 14 of Set 15 | mamakan
# Processing Record 15 of Set 15 | high rock
# Processing Record 16 of Set 15 | barranca
# Processing Record 17 of Set 15 | ludvika
# Processing Record 18 of Set 15 | bandar-e anzali
# Processing Record 19 of Set 15 | bell ville
# Processing Record 20 of Set 15 | aklavik
# Processing Record 21 of Set 15 | makakilo city
# Processing Record 22 of Set 15 | sarangani
# Processing Record 23 of Set 15 | agucadoura
# Processing Record 24 of Set 15 | guarda
# Processing Record 25 of Set 15 | chisec
# Processing Record 26 of Set 15 | liaozhong
# Processing Record 27 of Set 15 | celestun
# Processing Record 28 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 15 | santa maria del oro
# Processing Record 30 of Set 15 | halifax
# Processing Record 31 of Set 15 | nahrin
# Processing Record 32 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 33 of Set 15 | taoudenni
# Processing Record 34 of Set 15 | dalby
# Processing Record 35 of Set 15 | kargasok
# Processing Record 36 of Set 15 | yuli
# Processing Record 37 of Set 15 | moroto
# Processing Record 38 of Set 15 | ripoll
# Processing Record 39 of Set 15 | carutapera
# Processing Record 40 of Set 15 | acarau
# Processing Record 41 of Set 15 | general roca
# Processing Record 42 of Set 15 | north bend
# Processing Record 43 of Set 15 | tashtyp
# Processing Record 44 of Set 15 | raga
# Processing Record 45 of Set 15 | matinha
# Processing Record 46 of Set 15 | loiza
# Processing Record 47 of Set 15 | bartica
# Processing Record 48 of Set 15 | mount isa
# Processing Record 49 of Set 15 | bela vista
# Processing Record 50 of Set 15 | sangar
# Processing Record 1 of Set 16 | todos santos
# Processing Record 2 of Set 16 | keuruu
# Processing Record 3 of Set 16 | leh
# Processing Record 4 of Set 16 | sirjan
# Processing Record 5 of Set 16 | maloshuyka
# City not found. Skipping...
# Processing Record 6 of Set 16 | nizhniy kuranakh
# Processing Record 7 of Set 16 | vilyuysk
# Processing Record 8 of Set 16 | lagoa
# Processing Record 9 of Set 16 | calabozo
# Processing Record 10 of Set 16 | agirish
# Processing Record 11 of Set 16 | fergus falls
# Processing Record 12 of Set 16 | floro
# Processing Record 13 of Set 16 | otavi
# Processing Record 14 of Set 16 | temba
# Processing Record 15 of Set 16 | fortuna
# Processing Record 16 of Set 16 | penzance
# Processing Record 17 of Set 16 | svetlyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     52.05        64           3
# 1          Rikitea -23.1203 -134.9692     71.01        68          47
# 2           Bethel  41.3712  -73.4140     83.64        83           5
# 3             Hilo  19.7297 -155.0900     84.27        75          75
# 4       Harindanga  22.0383   88.3214     84.18        84          96
# 5          Ushuaia -54.8000  -68.3000     35.26        64          75
# 6          Iqaluit  63.7506  -68.5145     44.33        76          75
# 7         Yinchuan  38.4681  106.2731     62.01        46           0
# 8     Punta Arenas -53.1500  -70.9167     33.91        75          75
# 9  Arraial Do Cabo -22.9661  -42.0278     71.56        83           0
#
#    Wind Speed Country                 Date
# 0       11.32      AU  2021-08-24 23:35:04
# 1       11.43      PF  2021-08-24 23:31:57
# 2        3.67      US  2021-08-24 23:32:06
# 3       10.36      US  2021-08-24 23:32:09
# 4        6.22      IN  2021-08-24 23:35:05
# 5        5.75      AR  2021-08-24 23:32:00
# 6        3.44      CA  2021-08-24 23:29:51
# 7        3.47      CN  2021-08-24 23:35:05
# 8        2.30      CL  2021-08-24 23:30:43
# 9       18.41      BR  2021-08-24 23:32:02

# %%
# new_column_order = ["column2", "column4", "column1"]

#new_order= ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_order] 
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.6500  115.3333     52.05        64           3
# 1          Rikitea      PF -23.1203 -134.9692     71.01        68          47
# 2           Bethel      US  41.3712  -73.4140     83.64        83           5
# 3             Hilo      US  19.7297 -155.0900     84.27        75          75
# 4       Harindanga      IN  22.0383   88.3214     84.18        84          96
# 5          Ushuaia      AR -54.8000  -68.3000     35.26        64          75
# 6          Iqaluit      CA  63.7506  -68.5145     44.33        76          75
# 7         Yinchuan      CN  38.4681  106.2731     62.01        46           0
# 8     Punta Arenas      CL -53.1500  -70.9167     33.91        75          75
# 9  Arraial Do Cabo      BR -22.9661  -42.0278     71.56        83           0
#
#    Wind Speed
# 0       11.32
# 1       11.43
# 2        3.67
# 3       10.36
# 4        6.22
# 5        5.75
# 6        3.44
# 7        3.47
# 8        2.30
# 9       18.41

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
