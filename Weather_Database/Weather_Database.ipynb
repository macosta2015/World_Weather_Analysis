# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
#from config import weather_api_key
weather_api_key = "c334a28706460f469f090fde04b34da0"
# Import the datetime module from the datetime library.
from datetime import datetime
import json
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather
print(city_weather["weather"][0]["description"])
# Out:
# light rain

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | nerchinskiy zavod
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | svetlyy
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | port moresby
# Processing Record 9 of Set 1 | high level
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | caravelas
# Processing Record 13 of Set 1 | honiara
# Processing Record 14 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | gazanjyk
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | glace bay
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | narsaq
# Processing Record 26 of Set 1 | westport
# Processing Record 27 of Set 1 | baruun-urt
# Processing Record 28 of Set 1 | abong mbang
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | natchez
# Processing Record 32 of Set 1 | bessemer
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | ust-maya
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | turukhansk
# Processing Record 39 of Set 1 | hargeysa
# Processing Record 40 of Set 1 | namibe
# Processing Record 41 of Set 1 | natagaima
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | batagay-alyta
# Processing Record 44 of Set 1 | coahuayana
# Processing Record 45 of Set 1 | lipany
# Processing Record 46 of Set 1 | brae
# Processing Record 47 of Set 1 | ekibastuz
# Processing Record 48 of Set 1 | nagato
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 2 | karpathos
# Processing Record 4 of Set 2 | nara
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | naze
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | jasper
# Processing Record 11 of Set 2 | san andres
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 2 | mahajanga
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | bowral
# Processing Record 18 of Set 2 | bodden town
# Processing Record 19 of Set 2 | tongling
# Processing Record 20 of Set 2 | buchanan
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | kulhudhuffushi
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | tarko-sale
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | kaeo
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | salalah
# Processing Record 36 of Set 2 | changuinola
# Processing Record 37 of Set 2 | ughelli
# Processing Record 38 of Set 2 | kingaroy
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | la maddalena
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | athabasca
# Processing Record 46 of Set 2 | nishihara
# Processing Record 47 of Set 2 | luderitz
# Processing Record 48 of Set 2 | dinghai
# Processing Record 49 of Set 2 | bosaso
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | gushikawa
# Processing Record 2 of Set 3 | umm lajj
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | hazorasp
# Processing Record 5 of Set 3 | vardo
# Processing Record 6 of Set 3 | bilibino
# Processing Record 7 of Set 3 | marawi
# Processing Record 8 of Set 3 | trapani
# Processing Record 9 of Set 3 | sampit
# Processing Record 10 of Set 3 | salinopolis
# Processing Record 11 of Set 3 | usinsk
# Processing Record 12 of Set 3 | mount isa
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | north bend
# Processing Record 16 of Set 3 | samarai
# Processing Record 17 of Set 3 | viesca
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | surman
# Processing Record 22 of Set 3 | zapolyarnyy
# Processing Record 23 of Set 3 | leshukonskoye
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | high rock
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | stornoway
# Processing Record 29 of Set 3 | ketchikan
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | beloha
# Processing Record 32 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 3 | juybar
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | kavieng
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | egvekinot
# Processing Record 40 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | ngunguru
# Processing Record 43 of Set 3 | carutapera
# Processing Record 44 of Set 3 | shache
# Processing Record 45 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 3 | tsogni
# Processing Record 47 of Set 3 | hambantota
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | todos santos
# Processing Record 2 of Set 4 | shihezi
# Processing Record 3 of Set 4 | bluff
# Processing Record 4 of Set 4 | saint anthony
# Processing Record 5 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 4 | laguna
# Processing Record 7 of Set 4 | deutsch-wagram
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | mugur-aksy
# Processing Record 10 of Set 4 | hanmer springs
# Processing Record 11 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 4 | shobara
# Processing Record 13 of Set 4 | ludza
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | naifaru
# Processing Record 16 of Set 4 | jamestown
# Processing Record 17 of Set 4 | banjar
# Processing Record 18 of Set 4 | jizan
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | namatanai
# Processing Record 21 of Set 4 | bubaque
# Processing Record 22 of Set 4 | praia da vitoria
# Processing Record 23 of Set 4 | bouca
# Processing Record 24 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | talnakh
# Processing Record 27 of Set 4 | bairiki
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | lufilufi
# Processing Record 31 of Set 4 | okhotsk
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | baft
# Processing Record 35 of Set 4 | turkistan
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | manokwari
# Processing Record 38 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 4 | jawad
# Processing Record 40 of Set 4 | kahului
# Processing Record 41 of Set 4 | mangrol
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 4 | yashkul
# Processing Record 45 of Set 4 | klaksvik
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 48 of Set 4 | kautokeino
# Processing Record 49 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | hobart
# Processing Record 2 of Set 5 | stolin
# Processing Record 3 of Set 5 | ponta do sol
# Processing Record 4 of Set 5 | ilulissat
# Processing Record 5 of Set 5 | itoman
# Processing Record 6 of Set 5 | mehamn
# Processing Record 7 of Set 5 | mareeba
# Processing Record 8 of Set 5 | pinas
# Processing Record 9 of Set 5 | norrtalje
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | jomalig
# City not found. Skipping...
# Processing Record 13 of Set 5 | mbandaka
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | erenhot
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | saint leonard
# Processing Record 18 of Set 5 | belmonte
# Processing Record 19 of Set 5 | ballina
# Processing Record 20 of Set 5 | camocim
# Processing Record 21 of Set 5 | le port
# Processing Record 22 of Set 5 | loa janan
# Processing Record 23 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | ossora
# Processing Record 27 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | slobozia
# Processing Record 30 of Set 5 | nanakuli
# Processing Record 31 of Set 5 | kapaa
# Processing Record 32 of Set 5 | san juan
# Processing Record 33 of Set 5 | nicoya
# Processing Record 34 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 5 | sulangan
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | sovetskiy
# Processing Record 38 of Set 5 | safaga
# Processing Record 39 of Set 5 | canto do buriti
# Processing Record 40 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 41 of Set 5 | kununurra
# Processing Record 42 of Set 5 | sibolga
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | hokitika
# Processing Record 45 of Set 5 | maues
# Processing Record 46 of Set 5 | hualmay
# Processing Record 47 of Set 5 | aykino
# Processing Record 48 of Set 5 | altay
# Processing Record 49 of Set 5 | barrow
# Processing Record 50 of Set 5 | sioux lookout
# Processing Record 1 of Set 6 | norman wells
# Processing Record 2 of Set 6 | yining
# Processing Record 3 of Set 6 | nacunday
# City not found. Skipping...
# Processing Record 4 of Set 6 | te anau
# Processing Record 5 of Set 6 | zhigansk
# Processing Record 6 of Set 6 | iskateley
# Processing Record 7 of Set 6 | saint-georges
# Processing Record 8 of Set 6 | rehli
# Processing Record 9 of Set 6 | cidreira
# Processing Record 10 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 11 of Set 6 | peleduy
# Processing Record 12 of Set 6 | canico
# Processing Record 13 of Set 6 | myitkyina
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | adre
# Processing Record 16 of Set 6 | yulara
# Processing Record 17 of Set 6 | sorong
# Processing Record 18 of Set 6 | surgana
# Processing Record 19 of Set 6 | hadejia
# Processing Record 20 of Set 6 | cotonou
# Processing Record 21 of Set 6 | mahebourg
# Processing Record 22 of Set 6 | saldanha
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | xining
# Processing Record 25 of Set 6 | villacarrillo
# Processing Record 26 of Set 6 | raga
# Processing Record 27 of Set 6 | orodara
# Processing Record 28 of Set 6 | krasnoselkup
# Processing Record 29 of Set 6 | astoria
# Processing Record 30 of Set 6 | asau
# Processing Record 31 of Set 6 | nador
# Processing Record 32 of Set 6 | vilhena
# Processing Record 33 of Set 6 | kpalime
# Processing Record 34 of Set 6 | sao filipe
# Processing Record 35 of Set 6 | irati
# Processing Record 36 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 6 | bereda
# Processing Record 38 of Set 6 | nkayi
# Processing Record 39 of Set 6 | umm kaddadah
# Processing Record 40 of Set 6 | witzenhausen
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | soligalich
# Processing Record 43 of Set 6 | henties bay
# Processing Record 44 of Set 6 | mto wa mbu
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | mana
# Processing Record 47 of Set 6 | lasa
# Processing Record 48 of Set 6 | sabibah
# City not found. Skipping...
# Processing Record 49 of Set 6 | port elizabeth
# Processing Record 50 of Set 6 | alice town
# Processing Record 1 of Set 7 | buala
# Processing Record 2 of Set 7 | anshun
# Processing Record 3 of Set 7 | kavaratti
# Processing Record 4 of Set 7 | bonavista
# Processing Record 5 of Set 7 | impfondo
# Processing Record 6 of Set 7 | nuuk
# Processing Record 7 of Set 7 | pangnirtung
# Processing Record 8 of Set 7 | negotino
# Processing Record 9 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 10 of Set 7 | sun valley
# Processing Record 11 of Set 7 | vanimo
# Processing Record 12 of Set 7 | kalaleh
# Processing Record 13 of Set 7 | kutum
# Processing Record 14 of Set 7 | fairhope
# Processing Record 15 of Set 7 | whitianga
# Processing Record 16 of Set 7 | arkansas city
# Processing Record 17 of Set 7 | itamaraju
# Processing Record 18 of Set 7 | poum
# Processing Record 19 of Set 7 | vila velha
# Processing Record 20 of Set 7 | bundaberg
# Processing Record 21 of Set 7 | necochea
# Processing Record 22 of Set 7 | alyangula
# Processing Record 23 of Set 7 | tevaitoa
# Processing Record 24 of Set 7 | hammerfest
# Processing Record 25 of Set 7 | miri
# Processing Record 26 of Set 7 | rio gallegos
# Processing Record 27 of Set 7 | watertown
# Processing Record 28 of Set 7 | jalingo
# Processing Record 29 of Set 7 | yangambi
# Processing Record 30 of Set 7 | seljord
# Processing Record 31 of Set 7 | tiznit
# Processing Record 32 of Set 7 | buncrana
# Processing Record 33 of Set 7 | kattivakkam
# Processing Record 34 of Set 7 | tuatapere
# Processing Record 35 of Set 7 | sfantu gheorghe
# Processing Record 36 of Set 7 | half moon bay
# Processing Record 37 of Set 7 | malartic
# Processing Record 38 of Set 7 | leningradskiy
# Processing Record 39 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 40 of Set 7 | ajdabiya
# Processing Record 41 of Set 7 | sabanagrande
# Processing Record 42 of Set 7 | ust-kuyga
# Processing Record 43 of Set 7 | karratha
# Processing Record 44 of Set 7 | luganville
# Processing Record 45 of Set 7 | boa vista
# Processing Record 46 of Set 7 | ancud
# Processing Record 47 of Set 7 | la grande
# Processing Record 48 of Set 7 | praya
# Processing Record 49 of Set 7 | la paz
# Processing Record 50 of Set 7 | ambilobe
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 2 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 8 | manadhoo
# Processing Record 4 of Set 8 | tashtyp
# Processing Record 5 of Set 8 | sola
# Processing Record 6 of Set 8 | morondava
# Processing Record 7 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 8 | yei
# Processing Record 9 of Set 8 | morwell
# Processing Record 10 of Set 8 | lerwick
# Processing Record 11 of Set 8 | sabang
# Processing Record 12 of Set 8 | atar
# Processing Record 13 of Set 8 | vostok
# Processing Record 14 of Set 8 | airai
# Processing Record 15 of Set 8 | tucuma
# Processing Record 16 of Set 8 | rawson
# Processing Record 17 of Set 8 | lamu
# Processing Record 18 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 8 | mastic beach
# Processing Record 20 of Set 8 | meihekou
# Processing Record 21 of Set 8 | omboue
# Processing Record 22 of Set 8 | qasigiannguit
# Processing Record 23 of Set 8 | saint-augustin
# Processing Record 24 of Set 8 | zaysan
# Processing Record 25 of Set 8 | kalmunai
# Processing Record 26 of Set 8 | isangel
# Processing Record 27 of Set 8 | luwuk
# Processing Record 28 of Set 8 | tazovskiy
# Processing Record 29 of Set 8 | bisho
# Processing Record 30 of Set 8 | todi
# Processing Record 31 of Set 8 | santa maria
# Processing Record 32 of Set 8 | minggang
# Processing Record 33 of Set 8 | camacupa
# Processing Record 34 of Set 8 | hildburghausen
# Processing Record 35 of Set 8 | bathsheba
# Processing Record 36 of Set 8 | san borja
# Processing Record 37 of Set 8 | mbaiki
# Processing Record 38 of Set 8 | sauce
# Processing Record 39 of Set 8 | juneau
# Processing Record 40 of Set 8 | merritt
# Processing Record 41 of Set 8 | vila franca do campo
# Processing Record 42 of Set 8 | alekseyevka
# Processing Record 43 of Set 8 | turayf
# Processing Record 44 of Set 8 | kigoma
# Processing Record 45 of Set 8 | pacific grove
# Processing Record 46 of Set 8 | cabul-an
# Processing Record 47 of Set 8 | araouane
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | hobyo
# Processing Record 50 of Set 8 | olafsvik
# Processing Record 1 of Set 9 | zhigalovo
# Processing Record 2 of Set 9 | lisbon
# Processing Record 3 of Set 9 | lindsay
# Processing Record 4 of Set 9 | jalu
# Processing Record 5 of Set 9 | jacareacanga
# Processing Record 6 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 7 of Set 9 | boguchany
# Processing Record 8 of Set 9 | bambous virieux
# Processing Record 9 of Set 9 | kungurtug
# Processing Record 10 of Set 9 | olinda
# Processing Record 11 of Set 9 | santa cruz

# %%
len(city_data)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# new_column_order = ["column2", "column4", "column1"]

#new_order= ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current description"]
city_data_df = city_data_df[new_order] 
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
