# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

## Imports that we used in the modules, but were not needed for this deliverable.
# import matplotlib.pyplot as plt
# Import the time module.
# import time
# Import the datetime module from the datetime library.
# from datetime import datetime
# Import linear regression from the SciPy stats module.
# from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belaya gora
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | swellendam
# Processing Record 4 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | noumea
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | narsaq
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | yabrud
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | bouna
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | kingman
# Processing Record 21 of Set 1 | ayorou
# Processing Record 22 of Set 1 | el tigre
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | leh
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | kholodnyy
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | yashan
# Processing Record 32 of Set 1 | pangnirtung
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | kilindoni
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | baboua
# City not found. Skipping...
# Processing Record 39 of Set 1 | gazanjyk
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | ibi
# Processing Record 43 of Set 1 | asau
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | nieuw amsterdam
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 1 | esna
# Processing Record 49 of Set 1 | nome
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | unye
# City not found. Skipping...
# Processing Record 2 of Set 2 | isangel
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | yumen
# Processing Record 6 of Set 2 | qom
# Processing Record 7 of Set 2 | rodrigues alves
# Processing Record 8 of Set 2 | tura
# Processing Record 9 of Set 2 | bunia
# Processing Record 10 of Set 2 | wanning
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | waingapu
# Processing Record 13 of Set 2 | cabedelo
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 2 | khasan
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | kayes
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | arman
# Processing Record 25 of Set 2 | salym
# Processing Record 26 of Set 2 | port lincoln
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | piney green
# Processing Record 30 of Set 2 | aykhal
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | bismarck
# Processing Record 34 of Set 2 | kalmunai
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | boffa
# Processing Record 38 of Set 2 | tual
# Processing Record 39 of Set 2 | avera
# Processing Record 40 of Set 2 | huarmey
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | pailon
# Processing Record 43 of Set 2 | taltal
# Processing Record 44 of Set 2 | mabaruma
# Processing Record 45 of Set 2 | kimbe
# Processing Record 46 of Set 2 | port hardy
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | bandarbeyla
# Processing Record 50 of Set 2 | comodoro rivadavia
# Processing Record 1 of Set 3 | hami
# Processing Record 2 of Set 3 | naifaru
# Processing Record 3 of Set 3 | zaysan
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | nakatsugawa
# Processing Record 6 of Set 3 | caravelas
# Processing Record 7 of Set 3 | punta arenas
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | gombong
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | cumberland
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | kuah
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | aromashevo
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | buraydah
# Processing Record 21 of Set 3 | lubao
# Processing Record 22 of Set 3 | saskylakh
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | partizanskoye
# Processing Record 25 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 3 | rocha
# Processing Record 27 of Set 3 | opuwo
# Processing Record 28 of Set 3 | juneau
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | fort-shevchenko
# Processing Record 31 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 3 | bassar
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | husavik
# Processing Record 35 of Set 3 | muroto
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | drabiv
# Processing Record 38 of Set 3 | natal
# Processing Record 39 of Set 3 | taunggyi
# Processing Record 40 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | hovezi
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | mehamn
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | flinders
# Processing Record 47 of Set 3 | nikel
# Processing Record 48 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | voh
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | ponta do sol
# Processing Record 3 of Set 4 | chateaubelair
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | metro
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | beringovskiy
# Processing Record 8 of Set 4 | rawson
# Processing Record 9 of Set 4 | jaipur hat
# City not found. Skipping...
# Processing Record 10 of Set 4 | port-cartier
# Processing Record 11 of Set 4 | hit
# Processing Record 12 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | bryan
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | jalu
# Processing Record 18 of Set 4 | akersberga
# Processing Record 19 of Set 4 | hobyo
# Processing Record 20 of Set 4 | batagay-alyta
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | dezful
# Processing Record 23 of Set 4 | santa rosa
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | hearst
# Processing Record 27 of Set 4 | oistins
# Processing Record 28 of Set 4 | frankfort
# Processing Record 29 of Set 4 | afyonkarahisar
# Processing Record 30 of Set 4 | mokhotlong
# Processing Record 31 of Set 4 | chilliwack
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | paso de los toros
# Processing Record 34 of Set 4 | constantine
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | sinazongwe
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | yozgat
# Processing Record 40 of Set 4 | port blair
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 4 | zyryanka
# Processing Record 45 of Set 4 | siniscola
# Processing Record 46 of Set 4 | kochki
# Processing Record 47 of Set 4 | batagay
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | betsiamites
# Processing Record 50 of Set 4 | sovetskaya
# Processing Record 1 of Set 5 | barcelos
# Processing Record 2 of Set 5 | shingu
# Processing Record 3 of Set 5 | coari
# Processing Record 4 of Set 5 | talbahat
# Processing Record 5 of Set 5 | rio grande
# Processing Record 6 of Set 5 | roald
# Processing Record 7 of Set 5 | cordoba
# Processing Record 8 of Set 5 | simbahan
# Processing Record 9 of Set 5 | kamenka
# Processing Record 10 of Set 5 | beloha
# Processing Record 11 of Set 5 | grand gaube
# Processing Record 12 of Set 5 | inhambane
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | snasa
# Processing Record 19 of Set 5 | kontagora
# Processing Record 20 of Set 5 | esperance
# Processing Record 21 of Set 5 | tondon
# Processing Record 22 of Set 5 | vostok
# Processing Record 23 of Set 5 | praia da vitoria
# Processing Record 24 of Set 5 | xianshuigu
# Processing Record 25 of Set 5 | zapolyarnyy
# Processing Record 26 of Set 5 | plyussa
# Processing Record 27 of Set 5 | canmore
# Processing Record 28 of Set 5 | leshukonskoye
# Processing Record 29 of Set 5 | guanare
# Processing Record 30 of Set 5 | kununurra
# Processing Record 31 of Set 5 | henderson
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | barra do garcas
# Processing Record 34 of Set 5 | erice
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | qandala
# Processing Record 37 of Set 5 | tagusao
# Processing Record 38 of Set 5 | shelburne
# Processing Record 39 of Set 5 | envira
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | brenes
# Processing Record 42 of Set 5 | luanda
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | chokurdakh
# Processing Record 45 of Set 5 | poum
# Processing Record 46 of Set 5 | kavaratti
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | vestmanna
# Processing Record 49 of Set 5 | lasa
# Processing Record 50 of Set 5 | vikhorevka
# Processing Record 1 of Set 6 | zarubino
# Processing Record 2 of Set 6 | vitorino freire
# Processing Record 3 of Set 6 | marsaxlokk
# Processing Record 4 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 5 of Set 6 | imbituba
# Processing Record 6 of Set 6 | colares
# Processing Record 7 of Set 6 | miles city
# Processing Record 8 of Set 6 | kodinsk
# Processing Record 9 of Set 6 | mahibadhoo
# Processing Record 10 of Set 6 | pangody
# Processing Record 11 of Set 6 | lebu
# Processing Record 12 of Set 6 | zelenoborsk
# Processing Record 13 of Set 6 | pangkalanbuun
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | bourail
# Processing Record 16 of Set 6 | douglas
# Processing Record 17 of Set 6 | mozarlandia
# Processing Record 18 of Set 6 | avarua
# Processing Record 19 of Set 6 | haines junction
# Processing Record 20 of Set 6 | polyarnyy
# Processing Record 21 of Set 6 | rudnya
# Processing Record 22 of Set 6 | adrar
# Processing Record 23 of Set 6 | rundu
# Processing Record 24 of Set 6 | nabire
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | palu
# Processing Record 27 of Set 6 | senno
# Processing Record 28 of Set 6 | zabaykalsk
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 6 | sorland
# Processing Record 32 of Set 6 | chuy
# Processing Record 33 of Set 6 | acarau
# Processing Record 34 of Set 6 | bilma
# Processing Record 35 of Set 6 | komsomolskiy
# Processing Record 36 of Set 6 | bonoua
# Processing Record 37 of Set 6 | urengoy
# Processing Record 38 of Set 6 | sept-iles
# Processing Record 39 of Set 6 | aripuana
# Processing Record 40 of Set 6 | les cayes
# Processing Record 41 of Set 6 | vila velha
# Processing Record 42 of Set 6 | aksu
# Processing Record 43 of Set 6 | senanga
# Processing Record 44 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 6 | humaita
# Processing Record 46 of Set 6 | ust-nera
# Processing Record 47 of Set 6 | namatanai
# Processing Record 48 of Set 6 | burnie
# Processing Record 49 of Set 6 | tahoua
# Processing Record 50 of Set 6 | pangai
# Processing Record 1 of Set 7 | abha
# Processing Record 2 of Set 7 | longyearbyen
# Processing Record 3 of Set 7 | darhan
# Processing Record 4 of Set 7 | udachnyy
# Processing Record 5 of Set 7 | kurilsk
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | arlit
# Processing Record 8 of Set 7 | sovetskiy
# Processing Record 9 of Set 7 | sibolga
# Processing Record 10 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 7 | melito di porto salvo
# Processing Record 13 of Set 7 | dothan
# Processing Record 14 of Set 7 | pansemal
# Processing Record 15 of Set 7 | kampot
# Processing Record 16 of Set 7 | la ronge
# Processing Record 17 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 7 | phalodi
# Processing Record 19 of Set 7 | kahului
# Processing Record 20 of Set 7 | lae
# Processing Record 21 of Set 7 | nijar
# Processing Record 22 of Set 7 | chimbote
# Processing Record 23 of Set 7 | santa rosalia
# Processing Record 24 of Set 7 | marovoay
# Processing Record 25 of Set 7 | richards bay
# Processing Record 26 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 7 | derzhavinsk
# Processing Record 28 of Set 7 | los llanos de aridane
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | contamana
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | gizo
# Processing Record 33 of Set 7 | chumphon
# Processing Record 34 of Set 7 | andradina
# Processing Record 35 of Set 7 | yatou
# Processing Record 36 of Set 7 | orlik
# Processing Record 37 of Set 7 | myre
# Processing Record 38 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | sheridan
# Processing Record 40 of Set 7 | padang
# Processing Record 41 of Set 7 | qaqortoq
# Processing Record 42 of Set 7 | nhulunbuy
# Processing Record 43 of Set 7 | huilong
# Processing Record 44 of Set 7 | lata
# Processing Record 45 of Set 7 | tautira
# Processing Record 46 of Set 7 | yarkovo
# Processing Record 47 of Set 7 | murdochville
# Processing Record 48 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 7 | talnakh
# Processing Record 50 of Set 7 | corinto
# Processing Record 1 of Set 8 | nishihara
# Processing Record 2 of Set 8 | marsabit
# Processing Record 3 of Set 8 | nyrob
# Processing Record 4 of Set 8 | sioux lookout
# Processing Record 5 of Set 8 | cabra
# Processing Record 6 of Set 8 | celestun
# Processing Record 7 of Set 8 | conceicao da barra
# Processing Record 8 of Set 8 | izumo
# Processing Record 9 of Set 8 | uglegorsk
# Processing Record 10 of Set 8 | tatvan
# Processing Record 11 of Set 8 | kulhudhuffushi
# Processing Record 12 of Set 8 | fortuna foothills
# Processing Record 13 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 8 | pachino
# Processing Record 15 of Set 8 | abu zabad
# Processing Record 16 of Set 8 | saint-augustin
# Processing Record 17 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 8 | lowicz
# Processing Record 19 of Set 8 | saint george
# Processing Record 20 of Set 8 | clifton
# Processing Record 21 of Set 8 | cam ranh
# Processing Record 22 of Set 8 | kiunga
# Processing Record 23 of Set 8 | paciran
# Processing Record 24 of Set 8 | kasulu
# Processing Record 25 of Set 8 | glencoe
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | manokwari
# Processing Record 28 of Set 8 | hot springs
# Processing Record 29 of Set 8 | deputatskiy
# Processing Record 30 of Set 8 | bubaque
# Processing Record 31 of Set 8 | san patricio
# Processing Record 32 of Set 8 | halifax
# Processing Record 33 of Set 8 | airai
# Processing Record 34 of Set 8 | charlottesville
# Processing Record 35 of Set 8 | lithakia
# Processing Record 36 of Set 8 | tuapse
# Processing Record 37 of Set 8 | yeppoon
# Processing Record 38 of Set 8 | le port
# Processing Record 39 of Set 8 | gemena
# Processing Record 40 of Set 8 | khandbari
# Processing Record 41 of Set 8 | ocampo
# Processing Record 42 of Set 8 | nouadhibou
# Processing Record 43 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 8 | pandan
# Processing Record 45 of Set 8 | gimli
# Processing Record 46 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 8 | surt
# Processing Record 48 of Set 8 | challans
# Processing Record 49 of Set 8 | drumheller
# Processing Record 50 of Set 8 | toyooka
# Processing Record 1 of Set 9 | maneadero
# Processing Record 2 of Set 9 | samfya
# Processing Record 3 of Set 9 | davidson
# Processing Record 4 of Set 9 | kudahuvadhoo
# Processing Record 5 of Set 9 | chifeng
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | olonets
# Processing Record 8 of Set 9 | bonnyville
# Processing Record 9 of Set 9 | codrington
# Processing Record 10 of Set 9 | bandar-e lengeh
# Processing Record 11 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 12 of Set 9 | mayumba
# Processing Record 13 of Set 9 | coquimbo
# Processing Record 14 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | strzelce krajenskie
# Processing Record 16 of Set 9 | weihai
# Processing Record 17 of Set 9 | bavleny
# Processing Record 18 of Set 9 | nova olimpia
# Processing Record 19 of Set 9 | balakhta
# Processing Record 20 of Set 9 | ostrovnoy
# Processing Record 21 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 9 | alofi
# Processing Record 23 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 9 | grindavik
# Processing Record 25 of Set 9 | dormidontovka
# Processing Record 26 of Set 9 | san policarpo
# Processing Record 27 of Set 9 | broome
# Processing Record 28 of Set 9 | chicama
# Processing Record 29 of Set 9 | kastamonu
# Processing Record 30 of Set 9 | atar
# Processing Record 31 of Set 9 | mahebourg
# Processing Record 32 of Set 9 | paraiso
# Processing Record 33 of Set 9 | laguna
# Processing Record 34 of Set 9 | helong
# Processing Record 35 of Set 9 | sangar
# Processing Record 36 of Set 9 | chivay
# Processing Record 37 of Set 9 | ewa beach
# Processing Record 38 of Set 9 | evensk
# Processing Record 39 of Set 9 | rio gallegos
# Processing Record 40 of Set 9 | san antonio
# Processing Record 41 of Set 9 | puerto del rosario
# Processing Record 42 of Set 9 | isugod
# Processing Record 43 of Set 9 | namibe
# Processing Record 44 of Set 9 | arawa
# Processing Record 45 of Set 9 | myaundzha
# Processing Record 46 of Set 9 | dingle
# Processing Record 47 of Set 9 | miri
# Processing Record 48 of Set 9 | inuvik
# Processing Record 49 of Set 9 | sayyan
# Processing Record 50 of Set 9 | kysyl-syr
# Processing Record 1 of Set 10 | lumberton
# Processing Record 2 of Set 10 | luziania
# Processing Record 3 of Set 10 | mapiri
# Processing Record 4 of Set 10 | san vicente
# Processing Record 5 of Set 10 | klamath falls
# Processing Record 6 of Set 10 | half moon bay
# Processing Record 7 of Set 10 | farafangana
# Processing Record 8 of Set 10 | camacha
# Processing Record 9 of Set 10 | llangefni
# Processing Record 10 of Set 10 | sitka
# Processing Record 11 of Set 10 | moju
# Processing Record 12 of Set 10 | abalak
# Processing Record 13 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | kathu
# Processing Record 16 of Set 10 | pyay
# Processing Record 17 of Set 10 | ola
# Processing Record 18 of Set 10 | mareeba
# Processing Record 19 of Set 10 | sitrah
# Processing Record 20 of Set 10 | otsuchi
# Processing Record 21 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 10 | lavrentiya
# Processing Record 23 of Set 10 | rognan
# Processing Record 24 of Set 10 | posse
# Processing Record 25 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 26 of Set 10 | basco
# Processing Record 27 of Set 10 | kupang
# Processing Record 28 of Set 10 | exu
# Processing Record 29 of Set 10 | liepaja
# Processing Record 30 of Set 10 | sao joao da barra
# Processing Record 31 of Set 10 | sistranda
# Processing Record 32 of Set 10 | muli
# Processing Record 33 of Set 10 | san-pedro
# Processing Record 34 of Set 10 | nemuro
# Processing Record 35 of Set 10 | villazon
# Processing Record 36 of Set 10 | port hedland
# Processing Record 37 of Set 10 | olden
# Processing Record 38 of Set 10 | cape coast
# Processing Record 39 of Set 10 | khorixas
# Processing Record 40 of Set 10 | manado
# Processing Record 41 of Set 10 | goundam
# Processing Record 42 of Set 10 | marsa matruh
# Processing Record 43 of Set 10 | uyuni
# Processing Record 44 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 10 | kaura namoda
# Processing Record 46 of Set 10 | hesperia
# Processing Record 47 of Set 10 | melfi
# Processing Record 48 of Set 10 | pore
# Processing Record 49 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 10 | helena
# Processing Record 1 of Set 11 | olafsvik
# Processing Record 2 of Set 11 | antagan
# City not found. Skipping...
# Processing Record 3 of Set 11 | yuanping
# Processing Record 4 of Set 11 | kuusamo
# Processing Record 5 of Set 11 | zittau
# Processing Record 6 of Set 11 | cururupu
# Processing Record 7 of Set 11 | yaqui
# Processing Record 8 of Set 11 | shatrovo
# Processing Record 9 of Set 11 | petukhovo
# Processing Record 10 of Set 11 | piltene
# Processing Record 11 of Set 11 | san lawrenz
# Processing Record 12 of Set 11 | ukiah
# Processing Record 13 of Set 11 | havoysund
# Processing Record 14 of Set 11 | carinhanha
# Processing Record 15 of Set 11 | manadhoo
# Processing Record 16 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 11 | porbandar
# Processing Record 18 of Set 11 | hoima
# Processing Record 19 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 11 | nanakuli
# Processing Record 21 of Set 11 | fairbanks
# Processing Record 22 of Set 11 | dondo
# Processing Record 23 of Set 11 | sawtell
# Processing Record 24 of Set 11 | puerto baquerizo moreno
# Processing Record 25 of Set 11 | bousso
# Processing Record 26 of Set 11 | goiatuba
# Processing Record 27 of Set 11 | jishou
# Processing Record 28 of Set 11 | banjar
# Processing Record 29 of Set 11 | lukovetskiy
# Processing Record 30 of Set 11 | tomatlan
# Processing Record 31 of Set 11 | tavistock
# Processing Record 32 of Set 11 | livermore
# Processing Record 33 of Set 11 | bonavista
# Processing Record 34 of Set 11 | kosikha
# Processing Record 35 of Set 11 | changji
# Processing Record 36 of Set 11 | hun
# Processing Record 37 of Set 11 | presidencia roque saenz pena
# Processing Record 38 of Set 11 | maumere
# Processing Record 39 of Set 11 | touros
# Processing Record 40 of Set 11 | dharchula
# Processing Record 41 of Set 11 | khartoum
# Processing Record 42 of Set 11 | alice springs
# Processing Record 43 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 11 | genhe
# Processing Record 45 of Set 11 | ballina
# Processing Record 46 of Set 11 | bitkine
# Processing Record 47 of Set 11 | axim
# Processing Record 48 of Set 11 | togur
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | manakara
# Processing Record 1 of Set 12 | ahuimanu
# Processing Record 2 of Set 12 | sao gabriel da cachoeira
# Processing Record 3 of Set 12 | krasnoslobodsk
# Processing Record 4 of Set 12 | vestmannaeyjar
# Processing Record 5 of Set 12 | zonguldak
# Processing Record 6 of Set 12 | houston
# Processing Record 7 of Set 12 | dawlatabad
# Processing Record 8 of Set 12 | ponta pora
# Processing Record 9 of Set 12 | ust-tsilma
# Processing Record 10 of Set 12 | londiani
# Processing Record 11 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 12 | orel-izumrud
# Processing Record 13 of Set 12 | yerbogachen
# Processing Record 14 of Set 12 | apatou
# Processing Record 15 of Set 12 | amarante do maranhao
# Processing Record 16 of Set 12 | salalah
# Processing Record 17 of Set 12 | mayo
# Processing Record 18 of Set 12 | ndjole
# Processing Record 19 of Set 12 | tongliao
# Processing Record 20 of Set 12 | rehoboth
# Processing Record 21 of Set 12 | maun
# Processing Record 22 of Set 12 | lulea
# Processing Record 23 of Set 12 | luebo
# Processing Record 24 of Set 12 | saint anthony
# Processing Record 25 of Set 12 | troitsko-pechorsk
# Processing Record 26 of Set 12 | de aar
# Processing Record 27 of Set 12 | geraldton
# Processing Record 28 of Set 12 | maridi
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 12 | khorinsk
# Processing Record 32 of Set 12 | pochutla
# Processing Record 33 of Set 12 | kushima
# Processing Record 34 of Set 12 | aklavik
# Processing Record 35 of Set 12 | xingyi
# Processing Record 36 of Set 12 | faya
# Processing Record 37 of Set 12 | liberal
# Processing Record 38 of Set 12 | amahai
# Processing Record 39 of Set 12 | karasburg
# Processing Record 40 of Set 12 | maltahohe
# Processing Record 41 of Set 12 | takaka
# Processing Record 42 of Set 12 | ixtapa
# Processing Record 43 of Set 12 | semey
# Processing Record 44 of Set 12 | odweyne
# Processing Record 45 of Set 12 | atambua
# Processing Record 46 of Set 12 | makakilo city
# Processing Record 47 of Set 12 | vorukh
# Processing Record 48 of Set 12 | barranca
# Processing Record 49 of Set 12 | kolondieba
# Processing Record 50 of Set 12 | neuquen
# Processing Record 1 of Set 13 | dryden
# Processing Record 2 of Set 13 | devils lake
# Processing Record 3 of Set 13 | darien
# Processing Record 4 of Set 13 | voznesenye
# Processing Record 5 of Set 13 | qurayyat
# Processing Record 6 of Set 13 | mount isa
# Processing Record 7 of Set 13 | dadri
# Processing Record 8 of Set 13 | pringsewu
# Processing Record 9 of Set 13 | catuday
# Processing Record 10 of Set 13 | nizhniy tagil
# Processing Record 11 of Set 13 | puerto quijarro
# Processing Record 12 of Set 13 | vallenar
# Processing Record 13 of Set 13 | pindobacu
# Processing Record 14 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 15 of Set 13 | paita
# Processing Record 16 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 13 | tucuman
# Processing Record 18 of Set 13 | itaqui
# Processing Record 19 of Set 13 | torata
# Processing Record 20 of Set 13 | jiangyou
# Processing Record 21 of Set 13 | longuenesse
# Processing Record 22 of Set 13 | yar-sale
# Processing Record 23 of Set 13 | jacareacanga
# Processing Record 24 of Set 13 | calvinia
# Processing Record 25 of Set 13 | akyab
# Processing Record 26 of Set 13 | asosa
# Processing Record 27 of Set 13 | pandamatenga
# Processing Record 28 of Set 13 | yaan
# Processing Record 29 of Set 13 | eura
# Processing Record 30 of Set 13 | bukama
# Processing Record 31 of Set 13 | kisesa
# Processing Record 32 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 13 | jardim
# Processing Record 34 of Set 13 | cabo rojo
# Processing Record 35 of Set 13 | manggar
# Processing Record 36 of Set 13 | urgut
# Processing Record 37 of Set 13 | anadyr
# Processing Record 38 of Set 13 | dauriya
# Processing Record 39 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 13 | tuatapere
# Processing Record 41 of Set 13 | manta
# Processing Record 42 of Set 13 | benghazi
# Processing Record 43 of Set 13 | hambantota
# Processing Record 44 of Set 13 | whitehorse
# Processing Record 45 of Set 13 | marzuq
# Processing Record 46 of Set 13 | lively
# Processing Record 47 of Set 13 | vidim
# Processing Record 48 of Set 13 | kilcullen
# Processing Record 49 of Set 13 | luganville
# Processing Record 50 of Set 13 | bucerias
# Processing Record 1 of Set 14 | tobermory
# Processing Record 2 of Set 14 | cockburn town
# Processing Record 3 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 14 | san quintin
# Processing Record 5 of Set 14 | poquoson
# Processing Record 6 of Set 14 | russell
# Processing Record 7 of Set 14 | maningrida
# Processing Record 8 of Set 14 | hauge
# Processing Record 9 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 10 of Set 14 | sembe
# Processing Record 11 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 14 | samarai
# Processing Record 13 of Set 14 | sungaipenuh
# Processing Record 14 of Set 14 | vanimo
# Processing Record 15 of Set 14 | camopi
# Processing Record 16 of Set 14 | gladstone
# Processing Record 17 of Set 14 | general pico
# Processing Record 18 of Set 14 | pilar
# Processing Record 19 of Set 14 | karratha
# Processing Record 20 of Set 14 | kharan
# Processing Record 21 of Set 14 | almaznyy
# Processing Record 22 of Set 14 | gorontalo
# Processing Record 23 of Set 14 | sabang
# Processing Record 24 of Set 14 | dunedin
# Processing Record 25 of Set 14 | peniche
# Processing Record 26 of Set 14 | shihezi
# Processing Record 27 of Set 14 | kang
# Processing Record 28 of Set 14 | poltavka
# Processing Record 29 of Set 14 | sergeyevka
# Processing Record 30 of Set 14 | cruzilia
# Processing Record 31 of Set 14 | sidney
# Processing Record 32 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 14 | jumla
# Processing Record 34 of Set 14 | hastings
# Processing Record 35 of Set 14 | zhuhai
# Processing Record 36 of Set 14 | carlyle
# Processing Record 37 of Set 14 | tumut
# Processing Record 38 of Set 14 | rorvik
# Processing Record 39 of Set 14 | yurgamysh
# Processing Record 40 of Set 14 | carahue
# Processing Record 41 of Set 14 | alexandria
# Processing Record 42 of Set 14 | manati
# Processing Record 43 of Set 14 | partur
# Processing Record 44 of Set 14 | nautla
# Processing Record 45 of Set 14 | qasigiannguit
# Processing Record 46 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 14 | nelson bay
# Processing Record 48 of Set 14 | otane
# Processing Record 49 of Set 14 | lewistown
# Processing Record 50 of Set 14 | nogliki
# Processing Record 1 of Set 15 | moindou
# Processing Record 2 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 15 | molteno
# Processing Record 4 of Set 15 | casa grande
# Processing Record 5 of Set 15 | vieux-habitants
# Processing Record 6 of Set 15 | gwembe
# Processing Record 7 of Set 15 | bathsheba
# Processing Record 8 of Set 15 | shimoda
# Processing Record 9 of Set 15 | bowen
# Processing Record 10 of Set 15 | allahganj
# Processing Record 11 of Set 15 | narasannapeta
# Processing Record 12 of Set 15 | svetlyy
# Processing Record 13 of Set 15 | egvekinot
# Processing Record 14 of Set 15 | la romana
# Processing Record 15 of Set 15 | kristiinankaupunki
# Processing Record 16 of Set 15 | nam som
# Processing Record 17 of Set 15 | maceio
# Processing Record 18 of Set 15 | turbat
# Processing Record 19 of Set 15 | moses lake
# Processing Record 20 of Set 15 | dhidhdhoo
# Processing Record 21 of Set 15 | buala
# Processing Record 22 of Set 15 | kirakira
# Processing Record 23 of Set 15 | hameenlinna
# Processing Record 24 of Set 15 | uray
# Processing Record 25 of Set 15 | tecoh
# Processing Record 26 of Set 15 | espanola
# Processing Record 27 of Set 15 | gao
# Processing Record 28 of Set 15 | rabo de peixe
# Processing Record 29 of Set 15 | lons-le-saunier
# Processing Record 30 of Set 15 | hsintien
# City not found. Skipping...
# Processing Record 31 of Set 15 | lupeni
# Processing Record 32 of Set 15 | kailua
# Processing Record 33 of Set 15 | alta floresta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Belaya Gora      RU  68.53  146.42     -3.37        92          99
# 1        Hobart      AU -42.88  147.33     66.00        44          20
# 2    Swellendam      ZA -34.02   20.44     59.00        77           5
# 3        Albany      US  42.60  -73.97     51.01        93          75
# 4        Noumea      NC -22.28  166.46     80.60        54          90
# 5  Constitucion      CL -35.33  -72.42     57.97        70           0
# 6       Ushuaia      AR -54.80  -68.30     55.40        47          40
# 7       Rikitea      PF -23.12 -134.97     71.69        75         100
# 8        Narsaq      GL  60.92  -46.05     26.60        79         100
# 9        Torbay      CA  47.67  -52.73     37.00        74          90
#
#    Wind Speed Current Description
# 0        1.59     overcast clouds
# 1       13.87          few clouds
# 2        8.05           clear sky
# 3        2.98       broken clouds
# 4       13.87     overcast clouds
# 5        7.85           clear sky
# 6       18.34    scattered clouds
# 7       19.46     overcast clouds
# 8       10.29          light snow
# 9       17.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
